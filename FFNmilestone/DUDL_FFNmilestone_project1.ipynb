# %% [markdown]
# # COURSE: A deep understanding of deep learning
# ## SECTION: FFN milestone projects
# ### LECTURE: Project 1: A gratuitously complex adding machine
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/deeplearning_x/?couponCode=202401

# %%
# import libraries
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Create the training data

# %%
# create data

N = 2000

# generate data
data = torch.randint(low=-10,high=11,size=(N,2)).float()

# "labels"
labels = torch.sum(data,axis=1,keepdim=True)

# print the data
for i in range(N):
  print(data[i],labels[i])
# Out:
# tensor([10., -4.]) tensor([6.])
# tensor([-1., -7.]) tensor([-8.])
# tensor([ 1., -6.]) tensor([-5.])
# tensor([ -6., -10.]) tensor([-16.])
# tensor([3., 3.]) tensor([6.])
# tensor([10., -5.]) tensor([5.])
# tensor([8., 9.]) tensor([17.])
# tensor([6., 8.]) tensor([14.])
# tensor([8., 2.]) tensor([10.])
# tensor([-4., -5.]) tensor([-9.])
# tensor([-9.,  4.]) tensor([-5.])
# tensor([-7., -2.]) tensor([-9.])
# tensor([ 8., -9.]) tensor([-1.])
# tensor([-6.,  4.]) tensor([-2.])
# tensor([-1., -4.]) tensor([-5.])
# tensor([-8., -8.]) tensor([-16.])
# tensor([-5., -3.]) tensor([-8.])
# tensor([-8., -8.]) tensor([-16.])
# tensor([10., -2.]) tensor([8.])
# tensor([ 0., -4.]) tensor([-4.])
# tensor([-1.,  2.]) tensor([1.])
# tensor([-7.,  8.]) tensor([1.])
# tensor([-10.,   4.]) tensor([-6.])
# tensor([-2., -4.]) tensor([-6.])
# tensor([ 6., -6.]) tensor([0.])
# tensor([-3.,  6.]) tensor([3.])
# tensor([ 3., -8.]) tensor([-5.])
# tensor([-4.,  6.]) tensor([2.])
# tensor([ 9., -2.]) tensor([7.])
# tensor([-5.,  6.]) tensor([1.])
# tensor([5., 6.]) tensor([11.])
# tensor([6., 3.]) tensor([9.])
# tensor([-6.,  7.]) tensor([1.])
# tensor([ 6., -1.]) tensor([5.])
# tensor([9., 3.]) tensor([12.])
# tensor([-3., -1.]) tensor([-4.])
# tensor([ 9., 10.]) tensor([19.])
# tensor([6., 4.]) tensor([10.])
# tensor([5., 6.]) tensor([11.])
# tensor([4., 1.]) tensor([5.])
# tensor([ 0., -8.]) tensor([-8.])
# tensor([2., 5.]) tensor([7.])
# tensor([ 8., -4.]) tensor([4.])
# tensor([8., 9.]) tensor([17.])
# tensor([-8.,  2.]) tensor([-6.])
# tensor([2., 9.]) tensor([11.])
# tensor([-5.,  7.]) tensor([2.])
# tensor([-7., -5.]) tensor([-12.])
# tensor([ 9., -5.]) tensor([4.])
# tensor([-6., -3.]) tensor([-9.])
# tensor([ 5., -1.]) tensor([4.])
# tensor([ -6., -10.]) tensor([-16.])
# tensor([-3.,  2.]) tensor([-1.])
# tensor([-9., 10.]) tensor([1.])
# tensor([ 0., -8.]) tensor([-8.])
# tensor([7., 6.]) tensor([13.])
# tensor([-5.,  6.]) tensor([1.])
# tensor([-7.,  1.]) tensor([-6.])
# tensor([-6., -4.]) tensor([-10.])
# tensor([  0., -10.]) tensor([-10.])
# tensor([ 2., -5.]) tensor([-3.])
# tensor([ 4., -7.]) tensor([-3.])
# tensor([2., 5.]) tensor([7.])
# tensor([6., 7.]) tensor([13.])
# tensor([-7., -2.]) tensor([-9.])
# tensor([ 4., -3.]) tensor([1.])
# tensor([ 2., -7.]) tensor([-5.])
# tensor([9., 8.]) tensor([17.])
# tensor([-10.,   6.]) tensor([-4.])
# tensor([-4.,  2.]) tensor([-2.])
# tensor([-1.,  3.]) tensor([2.])
# tensor([ 1., -1.]) tensor([0.])
# tensor([ 8., -9.]) tensor([-1.])
# tensor([-4., 10.]) tensor([6.])
# tensor([5., 6.]) tensor([11.])
# tensor([ -2., -10.]) tensor([-12.])
# tensor([-10.,  -7.]) tensor([-17.])
# tensor([-7.,  3.]) tensor([-4.])
# tensor([-5., -3.]) tensor([-8.])
# tensor([ 2., -7.]) tensor([-5.])
# tensor([10.,  4.]) tensor([14.])
# tensor([2., 7.]) tensor([9.])
# tensor([-2.,  8.]) tensor([6.])
# tensor([ -4., -10.]) tensor([-14.])
# tensor([-4., -9.]) tensor([-13.])
# tensor([ 0., -8.]) tensor([-8.])
# tensor([-2.,  6.]) tensor([4.])
# tensor([-9.,  0.]) tensor([-9.])
# tensor([ 7., -4.]) tensor([3.])
# tensor([-5.,  3.]) tensor([-2.])
# tensor([ 3., -1.]) tensor([2.])
# tensor([-2., -4.]) tensor([-6.])
# tensor([0., 9.]) tensor([9.])
# tensor([-9.,  9.]) tensor([0.])
# tensor([-2., -9.]) tensor([-11.])
# tensor([-2.,  8.]) tensor([6.])
# tensor([-5., -1.]) tensor([-6.])
# tensor([8., 2.]) tensor([10.])
# tensor([1., 1.]) tensor([2.])
# tensor([ 1., 10.]) tensor([11.])
# tensor([-1., -7.]) tensor([-8.])
# tensor([9., 4.]) tensor([13.])
# tensor([5., 8.]) tensor([13.])
# tensor([-7.,  5.]) tensor([-2.])
# tensor([ 3., -9.]) tensor([-6.])
# tensor([7., 4.]) tensor([11.])
# tensor([-2., -8.]) tensor([-10.])
# tensor([ 5., -7.]) tensor([-2.])
# tensor([ 9., -3.]) tensor([6.])
# tensor([-8., -4.]) tensor([-12.])
# tensor([10., -6.]) tensor([4.])
# tensor([ 5., -4.]) tensor([1.])
# tensor([-6.,  7.]) tensor([1.])
# tensor([-2.,  8.]) tensor([6.])
# tensor([10.,  8.]) tensor([18.])
# tensor([8., 0.]) tensor([8.])
# tensor([-2.,  1.]) tensor([-1.])
# tensor([0., 8.]) tensor([8.])
# tensor([-7., -9.]) tensor([-16.])
# tensor([ 7., -3.]) tensor([4.])
# tensor([  2., -10.]) tensor([-8.])
# tensor([4., 9.]) tensor([13.])
# tensor([0., 0.]) tensor([0.])
# tensor([ 4., -1.]) tensor([3.])
# tensor([-9.,  0.]) tensor([-9.])
# tensor([9., 1.]) tensor([10.])
# tensor([ 3., -3.]) tensor([0.])
# tensor([-9., -2.]) tensor([-11.])
# tensor([-7.,  0.]) tensor([-7.])
# tensor([-6.,  5.]) tensor([-1.])
# tensor([-1.,  3.]) tensor([2.])
# tensor([3., 6.]) tensor([9.])
# tensor([  3., -10.]) tensor([-7.])
# tensor([-7., 10.]) tensor([3.])
# tensor([ 3., 10.]) tensor([13.])
# tensor([-7.,  4.]) tensor([-3.])
# tensor([-3., -3.]) tensor([-6.])
# tensor([ 0., -4.]) tensor([-4.])
# tensor([ -3., -10.]) tensor([-13.])
# tensor([1., 0.]) tensor([1.])
# tensor([  5., -10.]) tensor([-5.])
# tensor([-9.,  8.]) tensor([-1.])
# tensor([-7.,  3.]) tensor([-4.])
# tensor([-8.,  7.]) tensor([-1.])
# tensor([ 6., -6.]) tensor([0.])
# tensor([-8., -8.]) tensor([-16.])
# tensor([-10.,  -9.]) tensor([-19.])
# tensor([9., 3.]) tensor([12.])
# tensor([-2., -8.]) tensor([-10.])
# tensor([ 7., -4.]) tensor([3.])
# tensor([5., 8.]) tensor([13.])
# tensor([0., 9.]) tensor([9.])
# tensor([ 6., -1.]) tensor([5.])
# tensor([1., 1.]) tensor([2.])
# tensor([-4., -1.]) tensor([-5.])
# tensor([-10.,  -5.]) tensor([-15.])
# tensor([3., 9.]) tensor([12.])
# tensor([4., 2.]) tensor([6.])
# tensor([ 0., -4.]) tensor([-4.])
# tensor([-10.,  -3.]) tensor([-13.])
# tensor([1., 9.]) tensor([10.])
# tensor([10.,  0.]) tensor([10.])
# tensor([ 0., 10.]) tensor([10.])
# tensor([-4.,  1.]) tensor([-3.])
# tensor([-6., 10.]) tensor([4.])
# tensor([-7., -4.]) tensor([-11.])
# tensor([-7.,  3.]) tensor([-4.])
# tensor([-4., -4.]) tensor([-8.])
# tensor([-6., -6.]) tensor([-12.])
# tensor([0., 7.]) tensor([7.])
# tensor([ 5., 10.]) tensor([15.])
# tensor([ 0., -8.]) tensor([-8.])
# tensor([ 3., -5.]) tensor([-2.])
# tensor([8., 3.]) tensor([11.])
# tensor([-3.,  3.]) tensor([0.])
# tensor([ 7., -6.]) tensor([1.])
# tensor([-1.,  7.]) tensor([6.])
# tensor([5., 3.]) tensor([8.])
# tensor([ 5., -9.]) tensor([-4.])
# tensor([ 3., -2.]) tensor([1.])
# tensor([-1.,  8.]) tensor([7.])
# tensor([10.,  4.]) tensor([14.])
# tensor([1., 4.]) tensor([5.])
# tensor([-10.,  -3.]) tensor([-13.])
# tensor([10.,  8.]) tensor([18.])
# tensor([-1., -7.]) tensor([-8.])
# tensor([-3., -7.]) tensor([-10.])
# tensor([0., 9.]) tensor([9.])
# tensor([-7.,  0.]) tensor([-7.])
# tensor([-8.,  5.]) tensor([-3.])
# tensor([ 1., -6.]) tensor([-5.])
# tensor([6., 4.]) tensor([10.])
# tensor([ 1., -6.]) tensor([-5.])
# tensor([-6., -4.]) tensor([-10.])
# tensor([-6.,  4.]) tensor([-2.])
# tensor([ 4., -7.]) tensor([-3.])
# tensor([ 1., -9.]) tensor([-8.])
# tensor([-7., -1.]) tensor([-8.])
# tensor([4., 8.]) tensor([12.])
# tensor([-3., -2.]) tensor([-5.])
# tensor([  5., -10.]) tensor([-5.])
# tensor([-7., -7.]) tensor([-14.])
# tensor([ 5., -8.]) tensor([-3.])
# tensor([-6., -5.]) tensor([-11.])
# tensor([2., 6.]) tensor([8.])
# tensor([ 8., -3.]) tensor([5.])
# tensor([9., 5.]) tensor([14.])
# tensor([-4., -7.]) tensor([-11.])
# tensor([-1., -8.]) tensor([-9.])
# tensor([ 3., -9.]) tensor([-6.])
# tensor([7., 2.]) tensor([9.])
# tensor([  1., -10.]) tensor([-9.])
# tensor([4., 2.]) tensor([6.])
# tensor([-7.,  6.]) tensor([-1.])
# tensor([3., 7.]) tensor([10.])
# tensor([-7.,  6.]) tensor([-1.])
# tensor([-9.,  0.]) tensor([-9.])
# tensor([8., 1.]) tensor([9.])
# tensor([-9., -5.]) tensor([-14.])
# tensor([-4., -5.]) tensor([-9.])
# tensor([ 7., -2.]) tensor([5.])
# tensor([8., 4.]) tensor([12.])
# tensor([ 8., 10.]) tensor([18.])
# tensor([-5.,  0.]) tensor([-5.])
# tensor([10., -5.]) tensor([5.])
# tensor([-1., -9.]) tensor([-10.])
# tensor([ 7., -1.]) tensor([6.])
# tensor([-6., 10.]) tensor([4.])
# tensor([3., 0.]) tensor([3.])
# tensor([4., 6.]) tensor([10.])
# tensor([-8.,  6.]) tensor([-2.])
# tensor([  2., -10.]) tensor([-8.])
# tensor([ 6., -3.]) tensor([3.])
# tensor([ 8., -4.]) tensor([4.])
# tensor([-10., -10.]) tensor([-20.])
# tensor([-6., -1.]) tensor([-7.])
# tensor([-2., -2.]) tensor([-4.])
# tensor([0., 0.]) tensor([0.])
# tensor([9., 6.]) tensor([15.])
# tensor([-9.,  2.]) tensor([-7.])
# tensor([-9.,  4.]) tensor([-5.])
# tensor([7., 9.]) tensor([16.])
# tensor([-6., -3.]) tensor([-9.])
# tensor([4., 2.]) tensor([6.])
# tensor([-8.,  8.]) tensor([0.])
# tensor([-2., -2.]) tensor([-4.])
# tensor([ 2., -9.]) tensor([-7.])
# tensor([-6.,  9.]) tensor([3.])
# tensor([  0., -10.]) tensor([-10.])
# tensor([ 5., 10.]) tensor([15.])
# tensor([ 2., -6.]) tensor([-4.])
# tensor([ 3., -5.]) tensor([-2.])
# tensor([-1.,  5.]) tensor([4.])
# tensor([6., 7.]) tensor([13.])
# tensor([9., 9.]) tensor([18.])
# tensor([-4.,  3.]) tensor([-1.])
# tensor([-8., -9.]) tensor([-17.])
# tensor([7., 5.]) tensor([12.])
# tensor([6., 8.]) tensor([14.])
# tensor([1., 4.]) tensor([5.])
# tensor([ 1., 10.]) tensor([11.])
# tensor([ 6., -3.]) tensor([3.])
# tensor([-7., -2.]) tensor([-9.])
# tensor([2., 8.]) tensor([10.])
# tensor([ 2., -5.]) tensor([-3.])
# tensor([-5.,  2.]) tensor([-3.])
# tensor([3., 9.]) tensor([12.])
# tensor([-4.,  4.]) tensor([0.])
# tensor([-7.,  0.]) tensor([-7.])
# tensor([-2.,  1.]) tensor([-1.])
# tensor([6., 5.]) tensor([11.])
# tensor([7., 3.]) tensor([10.])
# tensor([ 6., -8.]) tensor([-2.])
# tensor([-5., -8.]) tensor([-13.])
# tensor([ 7., -4.]) tensor([3.])
# tensor([-2.,  3.]) tensor([1.])
# tensor([-6., -5.]) tensor([-11.])
# tensor([ 9., -6.]) tensor([3.])
# tensor([-10.,   8.]) tensor([-2.])
# tensor([-6., -5.]) tensor([-11.])
# tensor([-4.,  0.]) tensor([-4.])
# tensor([-7.,  3.]) tensor([-4.])
# tensor([-4., -7.]) tensor([-11.])
# tensor([ 2., -8.]) tensor([-6.])
# tensor([7., 9.]) tensor([16.])
# tensor([ 1., -5.]) tensor([-4.])
# tensor([9., 2.]) tensor([11.])
# tensor([-1.,  6.]) tensor([5.])
# tensor([ 0., -3.]) tensor([-3.])
# tensor([-7.,  4.]) tensor([-3.])
# tensor([ 5., -6.]) tensor([-1.])
# tensor([10., -6.]) tensor([4.])
# tensor([-8.,  5.]) tensor([-3.])
# tensor([ 3., -7.]) tensor([-4.])
# tensor([-8.,  8.]) tensor([0.])
# tensor([ 3., -3.]) tensor([0.])
# tensor([-2., -5.]) tensor([-7.])
# tensor([-7.,  6.]) tensor([-1.])
# tensor([-2.,  0.]) tensor([-2.])
# tensor([-4., -6.]) tensor([-10.])
# tensor([ -4., -10.]) tensor([-14.])
# tensor([2., 2.]) tensor([4.])
# tensor([-10.,   1.]) tensor([-9.])
# tensor([-5.,  0.]) tensor([-5.])
# tensor([-10.,   7.]) tensor([-3.])
# tensor([ 3., -9.]) tensor([-6.])
# tensor([-5.,  9.]) tensor([4.])
# tensor([10.,  8.]) tensor([18.])
# tensor([3., 8.]) tensor([11.])
# tensor([ 5., -9.]) tensor([-4.])
# tensor([  4., -10.]) tensor([-6.])
# tensor([3., 0.]) tensor([3.])
# tensor([ 8., -6.]) tensor([2.])
# tensor([-8., -5.]) tensor([-13.])
# tensor([7., 0.]) tensor([7.])
# tensor([ 4., -2.]) tensor([2.])
# tensor([-4., -9.]) tensor([-13.])
# tensor([-6.,  0.]) tensor([-6.])
# tensor([-8., -5.]) tensor([-13.])
# tensor([  5., -10.]) tensor([-5.])
# tensor([-1., -4.]) tensor([-5.])
# tensor([-9., -8.]) tensor([-17.])
# tensor([-10.,   6.]) tensor([-4.])
# tensor([6., 9.]) tensor([15.])
# tensor([-4.,  3.]) tensor([-1.])
# tensor([-6., 10.]) tensor([4.])
# tensor([-7., -5.]) tensor([-12.])
# tensor([-2., -3.]) tensor([-5.])
# tensor([-4., 10.]) tensor([6.])
# tensor([-1., -4.]) tensor([-5.])
# tensor([-2., -7.]) tensor([-9.])
# tensor([-10.,   1.]) tensor([-9.])
# tensor([-1., -9.]) tensor([-10.])
# tensor([-10.,   7.]) tensor([-3.])
# tensor([-5.,  4.]) tensor([-1.])
# tensor([ 8., 10.]) tensor([18.])
# tensor([9., 0.]) tensor([9.])
# tensor([-8., -6.]) tensor([-14.])
# tensor([ 5., -4.]) tensor([1.])
# tensor([4., 4.]) tensor([8.])
# tensor([9., 3.]) tensor([12.])
# tensor([ -9., -10.]) tensor([-19.])
# tensor([-3., -4.]) tensor([-7.])
# tensor([-3.,  2.]) tensor([-1.])
# tensor([ 4., -8.]) tensor([-4.])
# tensor([-8., -7.]) tensor([-15.])
# tensor([0., 3.]) tensor([3.])
# tensor([ 6., 10.]) tensor([16.])
# tensor([-7.,  1.]) tensor([-6.])
# tensor([ 6., -8.]) tensor([-2.])
# tensor([ 2., -5.]) tensor([-3.])
# tensor([ 7., -2.]) tensor([5.])
# tensor([-3.,  3.]) tensor([0.])
# tensor([-5., -3.]) tensor([-8.])
# tensor([10., 10.]) tensor([20.])
# tensor([-3., -2.]) tensor([-5.])
# tensor([6., 5.]) tensor([11.])
# tensor([ 7., -2.]) tensor([5.])
# tensor([-7.,  3.]) tensor([-4.])
# tensor([ 5., -7.]) tensor([-2.])
# tensor([-3., -5.]) tensor([-8.])
# tensor([ 4., -7.]) tensor([-3.])
# tensor([-9., -6.]) tensor([-15.])
# tensor([ -7., -10.]) tensor([-17.])
# tensor([-3.,  2.]) tensor([-1.])
# tensor([ -3., -10.]) tensor([-13.])
# tensor([-5., 10.]) tensor([5.])
# tensor([ 0., -6.]) tensor([-6.])
# tensor([-2., -7.]) tensor([-9.])
# tensor([-2., 10.]) tensor([8.])
# tensor([-9.,  6.]) tensor([-3.])
# tensor([1., 3.]) tensor([4.])
# tensor([  9., -10.]) tensor([-1.])
# tensor([-4.,  2.]) tensor([-2.])
# tensor([-6.,  9.]) tensor([3.])
# tensor([ 3., -5.]) tensor([-2.])
# tensor([-3.,  5.]) tensor([2.])
# tensor([-2.,  4.]) tensor([2.])
# tensor([-3., -4.]) tensor([-7.])
# tensor([  7., -10.]) tensor([-3.])
# tensor([-10.,  -8.]) tensor([-18.])
# tensor([ -3., -10.]) tensor([-13.])
# tensor([-8.,  8.]) tensor([0.])
# tensor([1., 9.]) tensor([10.])
# tensor([-7., -5.]) tensor([-12.])
# tensor([-8., -7.]) tensor([-15.])
# tensor([ 5., -4.]) tensor([1.])
# tensor([-1., -7.]) tensor([-8.])
# tensor([ 9., -5.]) tensor([4.])
# tensor([ 8., -4.]) tensor([4.])
# tensor([4., 3.]) tensor([7.])
# tensor([-5.,  4.]) tensor([-1.])
# tensor([-5.,  4.]) tensor([-1.])
# tensor([-5., -8.]) tensor([-13.])
# tensor([ 8., -3.]) tensor([5.])
# tensor([8., 4.]) tensor([12.])
# tensor([ 5., -9.]) tensor([-4.])
# tensor([-9.,  5.]) tensor([-4.])
# tensor([ 2., -2.]) tensor([0.])
# tensor([-2., -8.]) tensor([-10.])
# tensor([-2., -9.]) tensor([-11.])
# tensor([ 0., -2.]) tensor([-2.])
# tensor([1., 9.]) tensor([10.])
# tensor([7., 3.]) tensor([10.])
# tensor([-8.,  4.]) tensor([-4.])
# tensor([-9., -4.]) tensor([-13.])
# tensor([-9.,  2.]) tensor([-7.])
# tensor([6., 9.]) tensor([15.])
# tensor([ 4., -3.]) tensor([1.])
# tensor([ 7., -6.]) tensor([1.])
# tensor([7., 8.]) tensor([15.])
# tensor([7., 3.]) tensor([10.])
# tensor([ 2., -2.]) tensor([0.])
# tensor([-1., -8.]) tensor([-9.])
# tensor([-7.,  8.]) tensor([1.])
# tensor([-10.,  -4.]) tensor([-14.])
# tensor([-8., 10.]) tensor([2.])
# tensor([9., 8.]) tensor([17.])
# tensor([ 1., -7.]) tensor([-6.])
# tensor([ -7., -10.]) tensor([-17.])
# tensor([-4., -7.]) tensor([-11.])
# tensor([5., 1.]) tensor([6.])
# tensor([ 1., -4.]) tensor([-3.])
# tensor([10., -5.]) tensor([5.])
# tensor([5., 9.]) tensor([14.])
# tensor([ 2., -5.]) tensor([-3.])
# tensor([-6.,  4.]) tensor([-2.])
# tensor([4., 1.]) tensor([5.])
# tensor([4., 8.]) tensor([12.])
# tensor([6., 8.]) tensor([14.])
# tensor([-10.,  -3.]) tensor([-13.])
# tensor([-7., -9.]) tensor([-16.])
# tensor([ 1., -2.]) tensor([-1.])
# tensor([-5., -3.]) tensor([-8.])
# tensor([-6.,  6.]) tensor([0.])
# tensor([ 2., -9.]) tensor([-7.])
# tensor([-4.,  9.]) tensor([5.])
# tensor([0., 8.]) tensor([8.])
# tensor([-2., -9.]) tensor([-11.])
# tensor([-8., -1.]) tensor([-9.])
# tensor([ 3., -6.]) tensor([-3.])
# tensor([0., 3.]) tensor([3.])
# tensor([-2.,  8.]) tensor([6.])
# tensor([ 2., -3.]) tensor([-1.])
# tensor([ 7., -6.]) tensor([1.])
# tensor([-6.,  5.]) tensor([-1.])
# tensor([-4., -1.]) tensor([-5.])
# tensor([5., 6.]) tensor([11.])
# tensor([-1., -1.]) tensor([-2.])
# tensor([-7., -9.]) tensor([-16.])
# tensor([ 4., -7.]) tensor([-3.])
# tensor([-10.,  -1.]) tensor([-11.])
# tensor([-2.,  3.]) tensor([1.])
# tensor([3., 4.]) tensor([7.])
# tensor([ 7., -4.]) tensor([3.])
# tensor([-10.,   4.]) tensor([-6.])
# tensor([4., 8.]) tensor([12.])
# tensor([-9., -2.]) tensor([-11.])
# tensor([7., 4.]) tensor([11.])
# tensor([1., 2.]) tensor([3.])
# tensor([ 5., -7.]) tensor([-2.])
# tensor([6., 4.]) tensor([10.])
# tensor([10.,  5.]) tensor([15.])
# tensor([ 2., -4.]) tensor([-2.])
# tensor([-7.,  1.]) tensor([-6.])
# tensor([-2.,  9.]) tensor([7.])
# tensor([ 3., -1.]) tensor([2.])
# tensor([10., -3.]) tensor([7.])
# tensor([ 5., -8.]) tensor([-3.])
# tensor([6., 5.]) tensor([11.])
# tensor([-6.,  3.]) tensor([-3.])
# tensor([-5.,  6.]) tensor([1.])
# tensor([2., 4.]) tensor([6.])
# tensor([-6., -3.]) tensor([-9.])
# tensor([-5.,  6.]) tensor([1.])
# tensor([-3.,  7.]) tensor([4.])
# tensor([ 7., -5.]) tensor([2.])
# tensor([-6., -3.]) tensor([-9.])
# tensor([5., 4.]) tensor([9.])
# tensor([-4., -8.]) tensor([-12.])
# tensor([2., 2.]) tensor([4.])
# tensor([-5.,  4.]) tensor([-1.])
# tensor([5., 8.]) tensor([13.])
# tensor([ 3., -5.]) tensor([-2.])
# tensor([-3., 10.]) tensor([7.])
# tensor([7., 9.]) tensor([16.])
# tensor([7., 6.]) tensor([13.])
# tensor([ 2., -4.]) tensor([-2.])
# tensor([4., 7.]) tensor([11.])
# tensor([9., 9.]) tensor([18.])
# tensor([ 5., -9.]) tensor([-4.])
# tensor([6., 5.]) tensor([11.])
# tensor([-5.,  2.]) tensor([-3.])
# tensor([ 0., -8.]) tensor([-8.])
# tensor([10., 10.]) tensor([20.])
# tensor([ 8., -9.]) tensor([-1.])
# tensor([2., 7.]) tensor([9.])
# tensor([ 0., 10.]) tensor([10.])
# tensor([-6., -4.]) tensor([-10.])
# tensor([10., -5.]) tensor([5.])
# tensor([ 7., -5.]) tensor([2.])
# tensor([ 6., -9.]) tensor([-3.])
# tensor([6., 1.]) tensor([7.])
# tensor([7., 7.]) tensor([14.])
# tensor([-4., -4.]) tensor([-8.])
# tensor([-6.,  1.]) tensor([-5.])
# tensor([  5., -10.]) tensor([-5.])
# tensor([1., 6.]) tensor([7.])
# tensor([-3.,  6.]) tensor([3.])
# tensor([8., 8.]) tensor([16.])
# tensor([0., 6.]) tensor([6.])
# tensor([-6.,  9.]) tensor([3.])
# tensor([3., 0.]) tensor([3.])
# tensor([-4.,  0.]) tensor([-4.])
# tensor([-8., -2.]) tensor([-10.])
# tensor([ 10., -10.]) tensor([0.])
# tensor([ 2., -7.]) tensor([-5.])
# tensor([-9.,  1.]) tensor([-8.])
# tensor([-10.,  -7.]) tensor([-17.])
# tensor([6., 3.]) tensor([9.])
# tensor([ 9., -5.]) tensor([4.])
# tensor([-10.,  -2.]) tensor([-12.])
# tensor([ 3., -2.]) tensor([1.])
# tensor([-7.,  8.]) tensor([1.])
# tensor([ 5., -2.]) tensor([3.])
# tensor([-10.,   7.]) tensor([-3.])
# tensor([ 7., -5.]) tensor([2.])
# tensor([  6., -10.]) tensor([-4.])
# tensor([-2., -9.]) tensor([-11.])
# tensor([-7., -3.]) tensor([-10.])
# tensor([-10.,  -1.]) tensor([-11.])
# tensor([-1., -9.]) tensor([-10.])
# tensor([ 6., -1.]) tensor([5.])
# tensor([-5., -3.]) tensor([-8.])
# tensor([ 1., -6.]) tensor([-5.])
# tensor([ 4., 10.]) tensor([14.])
# tensor([-1.,  8.]) tensor([7.])
# tensor([ 1., -5.]) tensor([-4.])
# tensor([5., 5.]) tensor([10.])
# tensor([-1., -5.]) tensor([-6.])
# tensor([-4., -1.]) tensor([-5.])
# tensor([-10.,  -8.]) tensor([-18.])
# tensor([-4., -8.]) tensor([-12.])
# tensor([10., -9.]) tensor([1.])
# tensor([4., 9.]) tensor([13.])
# tensor([-10.,  -8.]) tensor([-18.])
# tensor([4., 7.]) tensor([11.])
# tensor([-10.,  -3.]) tensor([-13.])
# tensor([5., 5.]) tensor([10.])
# tensor([ 8., 10.]) tensor([18.])
# tensor([1., 4.]) tensor([5.])
# tensor([1., 4.]) tensor([5.])
# tensor([-5., -8.]) tensor([-13.])
# tensor([ 5., -1.]) tensor([4.])
# tensor([5., 8.]) tensor([13.])
# tensor([-6.,  3.]) tensor([-3.])
# tensor([ 4., -6.]) tensor([-2.])
# tensor([ 0., -1.]) tensor([-1.])
# tensor([-2., 10.]) tensor([8.])
# tensor([-9.,  5.]) tensor([-4.])
# tensor([-3.,  0.]) tensor([-3.])
# tensor([-6.,  6.]) tensor([0.])
# tensor([  4., -10.]) tensor([-6.])
# tensor([3., 2.]) tensor([5.])
# tensor([-5., -9.]) tensor([-14.])
# tensor([10., 10.]) tensor([20.])
# tensor([7., 3.]) tensor([10.])
# tensor([-5., -7.]) tensor([-12.])
# tensor([-1., -9.]) tensor([-10.])
# tensor([-2.,  3.]) tensor([1.])
# tensor([  7., -10.]) tensor([-3.])
# tensor([-7.,  5.]) tensor([-2.])
# tensor([-2., -5.]) tensor([-7.])
# tensor([ 3., -1.]) tensor([2.])
# tensor([ -1., -10.]) tensor([-11.])
# tensor([ 5., -7.]) tensor([-2.])
# tensor([-1., -6.]) tensor([-7.])
# tensor([ 0., 10.]) tensor([10.])
# tensor([-9., -4.]) tensor([-13.])
# tensor([-7.,  2.]) tensor([-5.])
# tensor([ 3., -6.]) tensor([-3.])
# tensor([-4., -6.]) tensor([-10.])
# tensor([5., 8.]) tensor([13.])
# tensor([-7.,  6.]) tensor([-1.])
# tensor([ 7., -8.]) tensor([-1.])
# tensor([6., 8.]) tensor([14.])
# tensor([-8.,  5.]) tensor([-3.])
# tensor([6., 9.]) tensor([15.])
# tensor([ -5., -10.]) tensor([-15.])
# tensor([2., 5.]) tensor([7.])
# tensor([ 7., -6.]) tensor([1.])
# tensor([-4., -7.]) tensor([-11.])
# tensor([5., 4.]) tensor([9.])
# tensor([-1.,  6.]) tensor([5.])
# tensor([-4., -2.]) tensor([-6.])
# tensor([ 6., -9.]) tensor([-3.])
# tensor([6., 6.]) tensor([12.])
# tensor([-1.,  5.]) tensor([4.])
# tensor([-9., 10.]) tensor([1.])
# tensor([5., 3.]) tensor([8.])
# tensor([ 9., -6.]) tensor([3.])
# tensor([ 8., -7.]) tensor([1.])
# tensor([6., 3.]) tensor([9.])
# tensor([-9.,  6.]) tensor([-3.])
# tensor([ -4., -10.]) tensor([-14.])
# tensor([-6.,  9.]) tensor([3.])
# tensor([8., 2.]) tensor([10.])
# tensor([-6., -4.]) tensor([-10.])
# tensor([-1.,  9.]) tensor([8.])
# tensor([ 3., -6.]) tensor([-3.])
# tensor([ 0., -8.]) tensor([-8.])
# tensor([-9., -5.]) tensor([-14.])
# tensor([ 3., -8.]) tensor([-5.])
# tensor([-9., -5.]) tensor([-14.])
# tensor([-3., -2.]) tensor([-5.])
# tensor([3., 6.]) tensor([9.])
# tensor([ 6., -6.]) tensor([0.])
# tensor([-1., 10.]) tensor([9.])
# tensor([-3.,  5.]) tensor([2.])
# tensor([-10.,  -4.]) tensor([-14.])
# tensor([10., -4.]) tensor([6.])
# tensor([ 2., -4.]) tensor([-2.])
# tensor([-7., -9.]) tensor([-16.])
# tensor([4., 5.]) tensor([9.])
# tensor([-10.,  -5.]) tensor([-15.])
# tensor([ 8., -6.]) tensor([2.])
# tensor([10.,  2.]) tensor([12.])
# tensor([-6.,  7.]) tensor([1.])
# tensor([10., -1.]) tensor([9.])
# tensor([ 3., -8.]) tensor([-5.])
# tensor([6., 2.]) tensor([8.])
# tensor([-8., -3.]) tensor([-11.])
# tensor([-6.,  1.]) tensor([-5.])
# tensor([-2., -4.]) tensor([-6.])
# tensor([-7., 10.]) tensor([3.])
# tensor([  4., -10.]) tensor([-6.])
# tensor([-2., -2.]) tensor([-4.])
# tensor([10.,  5.]) tensor([15.])
# tensor([10., -9.]) tensor([1.])
# tensor([-10.,  -1.]) tensor([-11.])
# tensor([-5.,  8.]) tensor([3.])
# tensor([-9., -1.]) tensor([-10.])
# tensor([3., 6.]) tensor([9.])
# tensor([ 2., -1.]) tensor([1.])
# tensor([ 7., -6.]) tensor([1.])
# tensor([-10., -10.]) tensor([-20.])
# tensor([3., 3.]) tensor([6.])
# tensor([ 9., -2.]) tensor([7.])
# tensor([-1.,  9.]) tensor([8.])
# tensor([-6.,  2.]) tensor([-4.])
# tensor([-10.,  10.]) tensor([0.])
# tensor([0., 9.]) tensor([9.])
# tensor([2., 8.]) tensor([10.])
# tensor([2., 7.]) tensor([9.])
# tensor([-6.,  3.]) tensor([-3.])
# tensor([-6., -6.]) tensor([-12.])
# tensor([ 1., -8.]) tensor([-7.])
# tensor([ 8., -3.]) tensor([5.])
# tensor([5., 6.]) tensor([11.])
# tensor([-9., -7.]) tensor([-16.])
# tensor([ 0., -5.]) tensor([-5.])
# tensor([10.,  9.]) tensor([19.])
# tensor([8., 5.]) tensor([13.])
# tensor([1., 4.]) tensor([5.])
# tensor([-10.,   8.]) tensor([-2.])
# tensor([ 9., 10.]) tensor([19.])
# tensor([ 2., -2.]) tensor([0.])
# tensor([-2., -3.]) tensor([-5.])
# tensor([6., 9.]) tensor([15.])
# tensor([-5.,  4.]) tensor([-1.])
# tensor([ 3., -8.]) tensor([-5.])
# tensor([9., 6.]) tensor([15.])
# tensor([-3.,  4.]) tensor([1.])
# tensor([9., 6.]) tensor([15.])
# tensor([ 9., -1.]) tensor([8.])
# tensor([-6.,  1.]) tensor([-5.])
# tensor([-6., -8.]) tensor([-14.])
# tensor([ 0., -4.]) tensor([-4.])
# tensor([-6.,  7.]) tensor([1.])
# tensor([10.,  6.]) tensor([16.])
# tensor([-10.,   7.]) tensor([-3.])
# tensor([ 0., -4.]) tensor([-4.])
# tensor([-5., -3.]) tensor([-8.])
# tensor([10.,  5.]) tensor([15.])
# tensor([-6., -2.]) tensor([-8.])
# tensor([ 3., -1.]) tensor([2.])
# tensor([5., 1.]) tensor([6.])
# tensor([ 4., -3.]) tensor([1.])
# tensor([-5.,  6.]) tensor([1.])
# tensor([ 3., -9.]) tensor([-6.])
# tensor([ 7., -1.]) tensor([6.])
# tensor([ 5., -2.]) tensor([3.])
# tensor([-3., -9.]) tensor([-12.])
# tensor([-3., -8.]) tensor([-11.])
# tensor([10., -1.]) tensor([9.])
# tensor([ 6., -3.]) tensor([3.])
# tensor([-5., -9.]) tensor([-14.])
# tensor([-6., -7.]) tensor([-13.])
# tensor([-10., -10.]) tensor([-20.])
# tensor([-6.,  9.]) tensor([3.])
# tensor([6., 1.]) tensor([7.])
# tensor([-2.,  6.]) tensor([4.])
# tensor([10.,  8.]) tensor([18.])
# tensor([ 10., -10.]) tensor([0.])
# tensor([4., 7.]) tensor([11.])
# tensor([ -9., -10.]) tensor([-19.])
# tensor([  3., -10.]) tensor([-7.])
# tensor([-9., -8.]) tensor([-17.])
# tensor([ 4., -5.]) tensor([-1.])
# tensor([-3., -3.]) tensor([-6.])
# tensor([ -6., -10.]) tensor([-16.])
# tensor([2., 3.]) tensor([5.])
# tensor([-1.,  6.]) tensor([5.])
# tensor([-3., -8.]) tensor([-11.])
# tensor([-4., -2.]) tensor([-6.])
# tensor([ 5., -5.]) tensor([0.])
# tensor([-9., -8.]) tensor([-17.])
# tensor([2., 9.]) tensor([11.])
# tensor([-4., 10.]) tensor([6.])
# tensor([-4., -1.]) tensor([-5.])
# tensor([ 7., -2.]) tensor([5.])
# tensor([ -6., -10.]) tensor([-16.])
# tensor([-7.,  6.]) tensor([-1.])
# tensor([  6., -10.]) tensor([-4.])
# tensor([9., 8.]) tensor([17.])
# tensor([ 7., -2.]) tensor([5.])
# tensor([-9.,  0.]) tensor([-9.])
# tensor([-5., -6.]) tensor([-11.])
# tensor([ -4., -10.]) tensor([-14.])
# tensor([-5., -8.]) tensor([-13.])
# tensor([-4., -3.]) tensor([-7.])
# tensor([ 7., -9.]) tensor([-2.])
# tensor([2., 9.]) tensor([11.])
# tensor([-10.,  10.]) tensor([0.])
# tensor([2., 8.]) tensor([10.])
# tensor([8., 3.]) tensor([11.])
# tensor([-5.,  6.]) tensor([1.])
# tensor([-4.,  8.]) tensor([4.])
# tensor([-2., -5.]) tensor([-7.])
# tensor([ 6., -6.]) tensor([0.])
# tensor([1., 5.]) tensor([6.])
# tensor([2., 8.]) tensor([10.])
# tensor([0., 1.]) tensor([1.])
# tensor([ 5., -9.]) tensor([-4.])
# tensor([ 8., -6.]) tensor([2.])
# tensor([ 3., -8.]) tensor([-5.])
# tensor([9., 8.]) tensor([17.])
# tensor([ 2., -4.]) tensor([-2.])
# tensor([5., 3.]) tensor([8.])
# tensor([5., 6.]) tensor([11.])
# tensor([-6., -2.]) tensor([-8.])
# tensor([-6.,  0.]) tensor([-6.])
# tensor([-1.,  6.]) tensor([5.])
# tensor([-2.,  1.]) tensor([-1.])
# tensor([-8.,  3.]) tensor([-5.])
# tensor([10.,  7.]) tensor([17.])
# tensor([-6.,  3.]) tensor([-3.])
# tensor([ 0., -7.]) tensor([-7.])
# tensor([0., 1.]) tensor([1.])
# tensor([-10.,   7.]) tensor([-3.])
# tensor([ 5., 10.]) tensor([15.])
# tensor([-10.,  -1.]) tensor([-11.])
# tensor([-9., -7.]) tensor([-16.])
# tensor([-9.,  6.]) tensor([-3.])
# tensor([-7.,  1.]) tensor([-6.])
# tensor([ 2., -5.]) tensor([-3.])
# tensor([ 4., 10.]) tensor([14.])
# tensor([ 10., -10.]) tensor([0.])
# tensor([10.,  8.]) tensor([18.])
# tensor([ 4., -3.]) tensor([1.])
# tensor([-1., 10.]) tensor([9.])
# tensor([-8.,  9.]) tensor([1.])
# tensor([-4.,  8.]) tensor([4.])
# tensor([ 5., 10.]) tensor([15.])
# tensor([-4.,  9.]) tensor([5.])
# tensor([-7.,  4.]) tensor([-3.])
# tensor([ -5., -10.]) tensor([-15.])
# tensor([-4.,  7.]) tensor([3.])
# tensor([ 6., -7.]) tensor([-1.])
# tensor([-8.,  2.]) tensor([-6.])
# tensor([ 7., -2.]) tensor([5.])
# tensor([-10.,   5.]) tensor([-5.])
# tensor([-6., -6.]) tensor([-12.])
# tensor([-6.,  3.]) tensor([-3.])
# tensor([-3., -7.]) tensor([-10.])
# tensor([1., 1.]) tensor([2.])
# tensor([-2.,  7.]) tensor([5.])
# tensor([10.,  7.]) tensor([17.])
# tensor([9., 6.]) tensor([15.])
# tensor([1., 8.]) tensor([9.])
# tensor([-4., -6.]) tensor([-10.])
# tensor([-1.,  1.]) tensor([0.])
# tensor([-1.,  6.]) tensor([5.])
# tensor([ 2., -7.]) tensor([-5.])
# tensor([7., 4.]) tensor([11.])
# tensor([ 2., 10.]) tensor([12.])
# tensor([-2.,  9.]) tensor([7.])
# tensor([ 2., -2.]) tensor([0.])
# tensor([-8., -3.]) tensor([-11.])
# tensor([-9.,  6.]) tensor([-3.])
# tensor([-3.,  8.]) tensor([5.])
# tensor([-10.,  -3.]) tensor([-13.])
# tensor([ 4., -1.]) tensor([3.])
# tensor([-3.,  3.]) tensor([0.])
# tensor([-9.,  2.]) tensor([-7.])
# tensor([-7., -5.]) tensor([-12.])
# tensor([9., 6.]) tensor([15.])
# tensor([10., 10.]) tensor([20.])
# tensor([-10.,   6.]) tensor([-4.])
# tensor([-1.,  4.]) tensor([3.])
# tensor([-4.,  6.]) tensor([2.])
# tensor([-7.,  9.]) tensor([2.])
# tensor([1., 6.]) tensor([7.])
# tensor([-10.,  -5.]) tensor([-15.])
# tensor([-3., -2.]) tensor([-5.])
# tensor([ 4., -6.]) tensor([-2.])
# tensor([8., 0.]) tensor([8.])
# tensor([ 6., -8.]) tensor([-2.])
# tensor([-10., -10.]) tensor([-20.])
# tensor([-5., -4.]) tensor([-9.])
# tensor([ 8., -5.]) tensor([3.])
# tensor([-4., -4.]) tensor([-8.])
# tensor([8., 7.]) tensor([15.])
# tensor([4., 4.]) tensor([8.])
# tensor([-5., -7.]) tensor([-12.])
# tensor([ 3., 10.]) tensor([13.])
# tensor([-5.,  8.]) tensor([3.])
# tensor([ 6., 10.]) tensor([16.])
# tensor([-10.,   6.]) tensor([-4.])
# tensor([-10.,  10.]) tensor([0.])
# tensor([-10.,   2.]) tensor([-8.])
# tensor([ 5., -1.]) tensor([4.])
# tensor([-3., -3.]) tensor([-6.])
# tensor([-9., -2.]) tensor([-11.])
# tensor([-8.,  2.]) tensor([-6.])
# tensor([-1.,  7.]) tensor([6.])
# tensor([  7., -10.]) tensor([-3.])
# tensor([-1.,  0.]) tensor([-1.])
# tensor([-2.,  7.]) tensor([5.])
# tensor([-10.,   9.]) tensor([-1.])
# tensor([3., 4.]) tensor([7.])
# tensor([10., -7.]) tensor([3.])
# tensor([6., 6.]) tensor([12.])
# tensor([-8.,  3.]) tensor([-5.])
# tensor([ 5., -9.]) tensor([-4.])
# tensor([1., 7.]) tensor([8.])
# tensor([-4., 10.]) tensor([6.])
# tensor([2., 4.]) tensor([6.])
# tensor([-3., -8.]) tensor([-11.])
# tensor([-10.,   6.]) tensor([-4.])
# tensor([-6.,  7.]) tensor([1.])
# tensor([-8.,  4.]) tensor([-4.])
# tensor([-1.,  6.]) tensor([5.])
# tensor([ 5., -2.]) tensor([3.])
# tensor([-3., -9.]) tensor([-12.])
# tensor([-2., -8.]) tensor([-10.])
# tensor([ 8., 10.]) tensor([18.])
# tensor([-10.,  -3.]) tensor([-13.])
# tensor([ 8., -2.]) tensor([6.])
# tensor([-5.,  8.]) tensor([3.])
# tensor([ 0., -6.]) tensor([-6.])
# tensor([  3., -10.]) tensor([-7.])
# tensor([4., 1.]) tensor([5.])
# tensor([8., 4.]) tensor([12.])
# tensor([ 9., -5.]) tensor([4.])
# tensor([ 7., -1.]) tensor([6.])
# tensor([-8.,  2.]) tensor([-6.])
# tensor([ 9., -6.]) tensor([3.])
# tensor([-10.,   7.]) tensor([-3.])
# tensor([9., 3.]) tensor([12.])
# tensor([ 2., -6.]) tensor([-4.])
# tensor([-3.,  4.]) tensor([1.])
# tensor([ 7., -4.]) tensor([3.])
# tensor([-10.,   3.]) tensor([-7.])
# tensor([-9.,  4.]) tensor([-5.])
# tensor([-4., -8.]) tensor([-12.])
# tensor([-3., -7.]) tensor([-10.])
# tensor([-2., -3.]) tensor([-5.])
# tensor([-7.,  8.]) tensor([1.])
# tensor([2., 0.]) tensor([2.])
# tensor([-3., -9.]) tensor([-12.])
# tensor([-2.,  7.]) tensor([5.])
# tensor([-1., -8.]) tensor([-9.])
# tensor([3., 3.]) tensor([6.])
# tensor([-10.,   3.]) tensor([-7.])
# tensor([-10.,   7.]) tensor([-3.])
# tensor([ 7., 10.]) tensor([17.])
# tensor([-2., -3.]) tensor([-5.])
# tensor([  4., -10.]) tensor([-6.])
# tensor([0., 7.]) tensor([7.])
# tensor([-10.,   6.]) tensor([-4.])
# tensor([ 1., -1.]) tensor([0.])
# tensor([-9., 10.]) tensor([1.])
# tensor([-6.,  9.]) tensor([3.])
# tensor([-1., -7.]) tensor([-8.])
# tensor([8., 1.]) tensor([9.])
# tensor([5., 9.]) tensor([14.])
# tensor([-8.,  8.]) tensor([0.])
# tensor([0., 8.]) tensor([8.])
# tensor([-2.,  4.]) tensor([2.])
# tensor([ 4., -4.]) tensor([0.])
# tensor([-3., -5.]) tensor([-8.])
# tensor([ 7., -6.]) tensor([1.])
# tensor([ 2., -7.]) tensor([-5.])
# tensor([-3., -3.]) tensor([-6.])
# tensor([9., 6.]) tensor([15.])
# tensor([2., 2.]) tensor([4.])
# tensor([ 6., -7.]) tensor([-1.])
# tensor([7., 0.]) tensor([7.])
# tensor([ 0., 10.]) tensor([10.])
# tensor([  0., -10.]) tensor([-10.])
# tensor([  0., -10.]) tensor([-10.])
# tensor([-2.,  5.]) tensor([3.])
# tensor([-6.,  7.]) tensor([1.])
# tensor([9., 8.]) tensor([17.])
# tensor([10., -6.]) tensor([4.])
# tensor([7., 9.]) tensor([16.])
# tensor([5., 4.]) tensor([9.])
# tensor([ 9., -8.]) tensor([1.])
# tensor([6., 5.]) tensor([11.])
# tensor([8., 6.]) tensor([14.])
# tensor([0., 0.]) tensor([0.])
# tensor([-5.,  9.]) tensor([4.])
# tensor([6., 4.]) tensor([10.])
# tensor([ 6., -8.]) tensor([-2.])
# tensor([10.,  2.]) tensor([12.])
# tensor([ 3., -6.]) tensor([-3.])
# tensor([-3., -3.]) tensor([-6.])
# tensor([-7., -8.]) tensor([-15.])
# tensor([ 3., -3.]) tensor([0.])
# tensor([ 1., -6.]) tensor([-5.])
# tensor([-6.,  4.]) tensor([-2.])
# tensor([  0., -10.]) tensor([-10.])
# tensor([-9.,  9.]) tensor([0.])
# tensor([ 3., -1.]) tensor([2.])
# tensor([-10.,   4.]) tensor([-6.])
# tensor([10.,  3.]) tensor([13.])
# tensor([-10.,  -5.]) tensor([-15.])
# tensor([-10.,  -2.]) tensor([-12.])
# tensor([-10.,   9.]) tensor([-1.])
# tensor([-9.,  0.]) tensor([-9.])
# tensor([9., 9.]) tensor([18.])
# tensor([-2., -2.]) tensor([-4.])
# tensor([-8.,  6.]) tensor([-2.])
# tensor([ 8., 10.]) tensor([18.])
# tensor([-2., -1.]) tensor([-3.])
# tensor([ 3., 10.]) tensor([13.])
# tensor([ 5., -4.]) tensor([1.])
# tensor([1., 6.]) tensor([7.])
# tensor([3., 3.]) tensor([6.])
# tensor([-4., -6.]) tensor([-10.])
# tensor([-2., -5.]) tensor([-7.])
# tensor([ 6., -9.]) tensor([-3.])
# tensor([9., 9.]) tensor([18.])
# tensor([ 6., -9.]) tensor([-3.])
# tensor([8., 0.]) tensor([8.])
# tensor([-1.,  8.]) tensor([7.])
# tensor([8., 7.]) tensor([15.])
# tensor([ 7., -9.]) tensor([-2.])
# tensor([-3., -4.]) tensor([-7.])
# tensor([ 3., -1.]) tensor([2.])
# tensor([-8., -9.]) tensor([-17.])
# tensor([6., 6.]) tensor([12.])
# tensor([-5., -4.]) tensor([-9.])
# tensor([-6.,  2.]) tensor([-4.])
# tensor([-7., -6.]) tensor([-13.])
# tensor([-9., -9.]) tensor([-18.])
# tensor([ 7., -4.]) tensor([3.])
# tensor([ -2., -10.]) tensor([-12.])
# tensor([8., 0.]) tensor([8.])
# tensor([-3., -5.]) tensor([-8.])
# tensor([ 9., -9.]) tensor([0.])
# tensor([-7.,  7.]) tensor([0.])
# tensor([ 2., -8.]) tensor([-6.])
# tensor([9., 7.]) tensor([16.])
# tensor([ 1., -5.]) tensor([-4.])
# tensor([2., 1.]) tensor([3.])
# tensor([-3., -5.]) tensor([-8.])
# tensor([ 1., -2.]) tensor([-1.])
# tensor([-7., -6.]) tensor([-13.])
# tensor([ 7., -4.]) tensor([3.])
# tensor([-3., -1.]) tensor([-4.])
# tensor([-9., -9.]) tensor([-18.])
# tensor([9., 7.]) tensor([16.])
# tensor([-8., -6.]) tensor([-14.])
# tensor([-8.,  2.]) tensor([-6.])
# tensor([8., 9.]) tensor([17.])
# tensor([ 1., -4.]) tensor([-3.])
# tensor([-1., -1.]) tensor([-2.])
# tensor([-5., -1.]) tensor([-6.])
# tensor([2., 7.]) tensor([9.])
# tensor([-1.,  6.]) tensor([5.])
# tensor([ 8., -2.]) tensor([6.])
# tensor([1., 2.]) tensor([3.])
# tensor([6., 4.]) tensor([10.])
# tensor([5., 8.]) tensor([13.])
# tensor([ 3., -2.]) tensor([1.])
# tensor([10.,  1.]) tensor([11.])
# tensor([-8.,  0.]) tensor([-8.])
# tensor([-7.,  8.]) tensor([1.])
# tensor([-6., -5.]) tensor([-11.])
# tensor([7., 7.]) tensor([14.])
# tensor([ 2., -9.]) tensor([-7.])
# tensor([4., 9.]) tensor([13.])
# tensor([ 7., -4.]) tensor([3.])
# tensor([-4., -2.]) tensor([-6.])
# tensor([-5., -6.]) tensor([-11.])
# tensor([0., 5.]) tensor([5.])
# tensor([ 5., -1.]) tensor([4.])
# tensor([2., 4.]) tensor([6.])
# tensor([-6.,  2.]) tensor([-4.])
# tensor([-5.,  9.]) tensor([4.])
# tensor([0., 7.]) tensor([7.])
# tensor([ 3., -5.]) tensor([-2.])
# tensor([-10., -10.]) tensor([-20.])
# tensor([-9.,  9.]) tensor([0.])
# tensor([ 3., -4.]) tensor([-1.])
# tensor([-7.,  6.]) tensor([-1.])
# tensor([-1.,  8.]) tensor([7.])
# tensor([-9., 10.]) tensor([1.])
# tensor([10., -5.]) tensor([5.])
# tensor([ 5., -1.]) tensor([4.])
# tensor([ 4., -5.]) tensor([-1.])
# tensor([-1.,  8.]) tensor([7.])
# tensor([10.,  6.]) tensor([16.])
# tensor([-5.,  0.]) tensor([-5.])
# tensor([10., -2.]) tensor([8.])
# tensor([-9.,  6.]) tensor([-3.])
# tensor([2., 2.]) tensor([4.])
# tensor([ 2., -3.]) tensor([-1.])
# tensor([-2.,  6.]) tensor([4.])
# tensor([ 7., -2.]) tensor([5.])
# tensor([-7.,  6.]) tensor([-1.])
# tensor([-6.,  5.]) tensor([-1.])
# tensor([6., 0.]) tensor([6.])
# tensor([3., 6.]) tensor([9.])
# tensor([-8.,  2.]) tensor([-6.])
# tensor([10., -9.]) tensor([1.])
# tensor([-5., -7.]) tensor([-12.])
# tensor([-3.,  1.]) tensor([-2.])
# tensor([-6.,  3.]) tensor([-3.])
# tensor([10., -3.]) tensor([7.])
# tensor([ 0., -4.]) tensor([-4.])
# tensor([4., 4.]) tensor([8.])
# tensor([-4., -4.]) tensor([-8.])
# tensor([-2.,  7.]) tensor([5.])
# tensor([3., 9.]) tensor([12.])
# tensor([-8., -3.]) tensor([-11.])
# tensor([-6., -3.]) tensor([-9.])
# tensor([ 7., -6.]) tensor([1.])
# tensor([-4.,  9.]) tensor([5.])
# tensor([4., 9.]) tensor([13.])
# tensor([4., 0.]) tensor([4.])
# tensor([10., -3.]) tensor([7.])
# tensor([-6.,  8.]) tensor([2.])
# tensor([-8., -3.]) tensor([-11.])
# tensor([-8.,  3.]) tensor([-5.])
# tensor([5., 9.]) tensor([14.])
# tensor([10.,  4.]) tensor([14.])
# tensor([-7., -2.]) tensor([-9.])
# tensor([2., 7.]) tensor([9.])
# tensor([-6., -2.]) tensor([-8.])
# tensor([ -6., -10.]) tensor([-16.])
# tensor([-2., -7.]) tensor([-9.])
# tensor([ 0., 10.]) tensor([10.])
# tensor([-5.,  3.]) tensor([-2.])
# tensor([-3.,  3.]) tensor([0.])
# tensor([-5., -9.]) tensor([-14.])
# tensor([-5.,  3.]) tensor([-2.])
# tensor([-4.,  7.]) tensor([3.])
# tensor([ 3., 10.]) tensor([13.])
# tensor([ 1., -6.]) tensor([-5.])
# tensor([-3.,  4.]) tensor([1.])
# tensor([-3.,  1.]) tensor([-2.])
# tensor([3., 2.]) tensor([5.])
# tensor([2., 9.]) tensor([11.])
# tensor([ -9., -10.]) tensor([-19.])
# tensor([-3.,  4.]) tensor([1.])
# tensor([7., 7.]) tensor([14.])
# tensor([  6., -10.]) tensor([-4.])
# tensor([-3.,  7.]) tensor([4.])
# tensor([-5.,  7.]) tensor([2.])
# tensor([ 9., -7.]) tensor([2.])
# tensor([ 8., -6.]) tensor([2.])
# tensor([2., 9.]) tensor([11.])
# tensor([ 7., 10.]) tensor([17.])
# tensor([ 1., -8.]) tensor([-7.])
# tensor([-9., -5.]) tensor([-14.])
# tensor([ 10., -10.]) tensor([0.])
# tensor([-5.,  7.]) tensor([2.])
# tensor([ 2., -6.]) tensor([-4.])
# tensor([7., 8.]) tensor([15.])
# tensor([-1.,  7.]) tensor([6.])
# tensor([-7.,  5.]) tensor([-2.])
# tensor([-10.,   4.]) tensor([-6.])
# tensor([ 6., -8.]) tensor([-2.])
# tensor([-8.,  8.]) tensor([0.])
# tensor([4., 3.]) tensor([7.])
# tensor([1., 3.]) tensor([4.])
# tensor([6., 6.]) tensor([12.])
# tensor([-9.,  0.]) tensor([-9.])
# tensor([6., 9.]) tensor([15.])
# tensor([-7.,  3.]) tensor([-4.])
# tensor([-5.,  8.]) tensor([3.])
# tensor([-5.,  2.]) tensor([-3.])
# tensor([-6., -1.]) tensor([-7.])
# tensor([ 1., -5.]) tensor([-4.])
# tensor([-9.,  8.]) tensor([-1.])
# tensor([-8.,  5.]) tensor([-3.])
# tensor([-4., -9.]) tensor([-13.])
# tensor([ 7., -9.]) tensor([-2.])
# tensor([4., 3.]) tensor([7.])
# tensor([ 0., -2.]) tensor([-2.])
# tensor([-4., -9.]) tensor([-13.])
# tensor([ 2., -8.]) tensor([-6.])
# tensor([8., 0.]) tensor([8.])
# tensor([-6.,  4.]) tensor([-2.])
# tensor([-10.,   0.]) tensor([-10.])
# tensor([ 5., -5.]) tensor([0.])
# tensor([  3., -10.]) tensor([-7.])
# tensor([ 9., -3.]) tensor([6.])
# tensor([5., 7.]) tensor([12.])
# tensor([-3., -4.]) tensor([-7.])
# tensor([9., 1.]) tensor([10.])
# tensor([-8., -1.]) tensor([-9.])
# tensor([ -1., -10.]) tensor([-11.])
# tensor([-7., -6.]) tensor([-13.])
# tensor([ 4., -5.]) tensor([-1.])
# tensor([-10.,   6.]) tensor([-4.])
# tensor([-10.,   9.]) tensor([-1.])
# tensor([-6.,  5.]) tensor([-1.])
# tensor([-10.,   5.]) tensor([-5.])
# tensor([-1.,  4.]) tensor([3.])
# tensor([-9., -1.]) tensor([-10.])
# tensor([ 0., -2.]) tensor([-2.])
# tensor([-5.,  9.]) tensor([4.])
# tensor([-8., -9.]) tensor([-17.])
# tensor([-10.,  -2.]) tensor([-12.])
# tensor([5., 0.]) tensor([5.])
# tensor([ 1., -4.]) tensor([-3.])
# tensor([-2.,  6.]) tensor([4.])
# tensor([ 6., 10.]) tensor([16.])
# tensor([7., 7.]) tensor([14.])
# tensor([0., 7.]) tensor([7.])
# tensor([9., 7.]) tensor([16.])
# tensor([-7., -5.]) tensor([-12.])
# tensor([4., 4.]) tensor([8.])
# tensor([ 4., -6.]) tensor([-2.])
# tensor([-3., -5.]) tensor([-8.])
# tensor([-10.,  -6.]) tensor([-16.])
# tensor([ 0., -3.]) tensor([-3.])
# tensor([0., 5.]) tensor([5.])
# tensor([-1.,  3.]) tensor([2.])
# tensor([-2.,  3.]) tensor([1.])
# tensor([-5., -2.]) tensor([-7.])
# tensor([7., 1.]) tensor([8.])
# tensor([4., 6.]) tensor([10.])
# tensor([ 8., -5.]) tensor([3.])
# tensor([-3., -3.]) tensor([-6.])
# tensor([1., 6.]) tensor([7.])
# tensor([-1., -6.]) tensor([-7.])
# tensor([-5.,  4.]) tensor([-1.])
# tensor([-2.,  6.]) tensor([4.])
# tensor([10., -5.]) tensor([5.])
# tensor([-4.,  9.]) tensor([5.])
# tensor([ 2., -9.]) tensor([-7.])
# tensor([ 5., -3.]) tensor([2.])
# tensor([-2., -3.]) tensor([-5.])
# tensor([ 2., -2.]) tensor([0.])
# tensor([-5.,  5.]) tensor([0.])
# tensor([ 2., -7.]) tensor([-5.])
# tensor([-10.,   5.]) tensor([-5.])
# tensor([7., 9.]) tensor([16.])
# tensor([-4.,  7.]) tensor([3.])
# tensor([-3., -9.]) tensor([-12.])
# tensor([ 5., -7.]) tensor([-2.])
# tensor([-6.,  0.]) tensor([-6.])
# tensor([ 0., -4.]) tensor([-4.])
# tensor([-4., -2.]) tensor([-6.])
# tensor([ 0., -1.]) tensor([-1.])
# tensor([-8., -5.]) tensor([-13.])
# tensor([-6., -8.]) tensor([-14.])
# tensor([-6., -5.]) tensor([-11.])
# tensor([ 0., -1.]) tensor([-1.])
# tensor([3., 5.]) tensor([8.])
# tensor([-5., -2.]) tensor([-7.])
# tensor([-6., -3.]) tensor([-9.])
# tensor([2., 9.]) tensor([11.])
# tensor([-2.,  6.]) tensor([4.])
# tensor([-7., -8.]) tensor([-15.])
# tensor([-6.,  2.]) tensor([-4.])
# tensor([-9.,  1.]) tensor([-8.])
# tensor([  1., -10.]) tensor([-9.])
# tensor([-9.,  5.]) tensor([-4.])
# tensor([9., 6.]) tensor([15.])
# tensor([3., 7.]) tensor([10.])
# tensor([ 8., 10.]) tensor([18.])
# tensor([ 8., -6.]) tensor([2.])
# tensor([-6., -2.]) tensor([-8.])
# tensor([-5., -9.]) tensor([-14.])
# tensor([ 7., -7.]) tensor([0.])
# tensor([ 1., -7.]) tensor([-6.])
# tensor([-8.,  2.]) tensor([-6.])
# tensor([-7.,  6.]) tensor([-1.])
# tensor([ 1., -1.]) tensor([0.])
# tensor([  6., -10.]) tensor([-4.])
# tensor([ 0., -6.]) tensor([-6.])
# tensor([-7., -7.]) tensor([-14.])
# tensor([-7.,  5.]) tensor([-2.])
# tensor([ 3., -9.]) tensor([-6.])
# tensor([-3.,  4.]) tensor([1.])
# tensor([-6., -6.]) tensor([-12.])
# tensor([ 0., -8.]) tensor([-8.])
# tensor([ 6., -2.]) tensor([4.])
# tensor([1., 1.]) tensor([2.])
# tensor([-4.,  0.]) tensor([-4.])
# tensor([ 6., 10.]) tensor([16.])
# tensor([-2.,  4.]) tensor([2.])
# tensor([-9.,  4.]) tensor([-5.])
# tensor([3., 4.]) tensor([7.])
# tensor([-5.,  2.]) tensor([-3.])
# tensor([10.,  7.]) tensor([17.])
# tensor([  7., -10.]) tensor([-3.])
# tensor([4., 9.]) tensor([13.])
# tensor([ 8., -8.]) tensor([0.])
# tensor([-8., -1.]) tensor([-9.])
# tensor([ 6., -4.]) tensor([2.])
# tensor([-5., -7.]) tensor([-12.])
# tensor([4., 7.]) tensor([11.])
# tensor([ 3., -9.]) tensor([-6.])
# tensor([1., 5.]) tensor([6.])
# tensor([4., 7.]) tensor([11.])
# tensor([-7.,  4.]) tensor([-3.])
# tensor([4., 7.]) tensor([11.])
# tensor([ 3., -4.]) tensor([-1.])
# tensor([6., 9.]) tensor([15.])
# tensor([-8.,  6.]) tensor([-2.])
# tensor([-3.,  7.]) tensor([4.])
# tensor([-10.,   9.]) tensor([-1.])
# tensor([ 5., -9.]) tensor([-4.])
# tensor([-7.,  5.]) tensor([-2.])
# tensor([-10.,  10.]) tensor([0.])
# tensor([-7.,  6.]) tensor([-1.])
# tensor([-6., -6.]) tensor([-12.])
# tensor([4., 1.]) tensor([5.])
# tensor([ 4., -1.]) tensor([3.])
# tensor([  3., -10.]) tensor([-7.])
# tensor([ 3., -4.]) tensor([-1.])
# tensor([8., 7.]) tensor([15.])
# tensor([-9.,  9.]) tensor([0.])
# tensor([ 5., -2.]) tensor([3.])
# tensor([ 5., -8.]) tensor([-3.])
# tensor([9., 8.]) tensor([17.])
# tensor([-7., -3.]) tensor([-10.])
# tensor([2., 4.]) tensor([6.])
# tensor([7., 7.]) tensor([14.])
# tensor([0., 9.]) tensor([9.])
# tensor([8., 5.]) tensor([13.])
# tensor([ 1., -4.]) tensor([-3.])
# tensor([ 6., -8.]) tensor([-2.])
# tensor([-2.,  6.]) tensor([4.])
# tensor([-3., -4.]) tensor([-7.])
# tensor([8., 0.]) tensor([8.])
# tensor([-10.,   7.]) tensor([-3.])
# tensor([ -8., -10.]) tensor([-18.])
# tensor([5., 0.]) tensor([5.])
# tensor([-1.,  9.]) tensor([8.])
# tensor([0., 4.]) tensor([4.])
# tensor([-1.,  5.]) tensor([4.])
# tensor([ 7., 10.]) tensor([17.])
# tensor([10.,  0.]) tensor([10.])
# tensor([ -8., -10.]) tensor([-18.])
# tensor([-1., -8.]) tensor([-9.])
# tensor([-5.,  6.]) tensor([1.])
# tensor([-6.,  0.]) tensor([-6.])
# tensor([ 0., -1.]) tensor([-1.])
# tensor([ 3., -8.]) tensor([-5.])
# tensor([-3., -7.]) tensor([-10.])
# tensor([0., 6.]) tensor([6.])
# tensor([-3., -8.]) tensor([-11.])
# tensor([-7.,  4.]) tensor([-3.])
# tensor([ 6., -2.]) tensor([4.])
# tensor([4., 6.]) tensor([10.])
# tensor([-2., 10.]) tensor([8.])
# tensor([1., 9.]) tensor([10.])
# tensor([ 9., -6.]) tensor([3.])
# tensor([ 9., -7.]) tensor([2.])
# tensor([0., 0.]) tensor([0.])
# tensor([-7.,  7.]) tensor([0.])
# tensor([3., 0.]) tensor([3.])
# tensor([-1., -8.]) tensor([-9.])
# tensor([-8., -5.]) tensor([-13.])
# tensor([ 3., -3.]) tensor([0.])
# tensor([6., 9.]) tensor([15.])
# tensor([-10.,   1.]) tensor([-9.])
# tensor([  9., -10.]) tensor([-1.])
# tensor([ 5., -4.]) tensor([1.])
# tensor([-10.,  -4.]) tensor([-14.])
# tensor([-3., -5.]) tensor([-8.])
# tensor([7., 1.]) tensor([8.])
# tensor([0., 3.]) tensor([3.])
# tensor([6., 7.]) tensor([13.])
# tensor([-5.,  8.]) tensor([3.])
# tensor([-2.,  5.]) tensor([3.])
# tensor([-6.,  0.]) tensor([-6.])
# tensor([10., -4.]) tensor([6.])
# tensor([5., 0.]) tensor([5.])
# tensor([6., 0.]) tensor([6.])
# tensor([ 7., 10.]) tensor([17.])
# tensor([3., 2.]) tensor([5.])
# tensor([-10.,  -5.]) tensor([-15.])
# tensor([-2., -2.]) tensor([-4.])
# tensor([-8., -7.]) tensor([-15.])
# tensor([10., -1.]) tensor([9.])
# tensor([-5., -7.]) tensor([-12.])
# tensor([-8., 10.]) tensor([2.])
# tensor([-1.,  7.]) tensor([6.])
# tensor([-3.,  2.]) tensor([-1.])
# tensor([-9., -6.]) tensor([-15.])
# tensor([-3.,  2.]) tensor([-1.])
# tensor([-3.,  5.]) tensor([2.])
# tensor([-6.,  8.]) tensor([2.])
# tensor([-5.,  1.]) tensor([-4.])
# tensor([-10.,  10.]) tensor([0.])
# tensor([10., -8.]) tensor([2.])
# tensor([-4.,  4.]) tensor([0.])
# tensor([ 5., -6.]) tensor([-1.])
# tensor([-2.,  6.]) tensor([4.])
# tensor([9., 8.]) tensor([17.])
# tensor([ 9., -2.]) tensor([7.])
# tensor([2., 8.]) tensor([10.])
# tensor([-10.,  -5.]) tensor([-15.])
# tensor([-5.,  8.]) tensor([3.])
# tensor([-1.,  8.]) tensor([7.])
# tensor([ 7., -3.]) tensor([4.])
# tensor([4., 7.]) tensor([11.])
# tensor([-2.,  6.]) tensor([4.])
# tensor([ 9., -3.]) tensor([6.])
# tensor([-1.,  9.]) tensor([8.])
# tensor([ 3., -9.]) tensor([-6.])
# tensor([2., 5.]) tensor([7.])
# tensor([9., 4.]) tensor([13.])
# tensor([6., 2.]) tensor([8.])
# tensor([10., -8.]) tensor([2.])
# tensor([-7.,  9.]) tensor([2.])
# tensor([8., 7.]) tensor([15.])
# tensor([-1., -9.]) tensor([-10.])
# tensor([ 7., -8.]) tensor([-1.])
# tensor([-10.,  -7.]) tensor([-17.])
# tensor([9., 0.]) tensor([9.])
# tensor([-7.,  3.]) tensor([-4.])
# tensor([ 9., -1.]) tensor([8.])
# tensor([5., 6.]) tensor([11.])
# tensor([-7.,  8.]) tensor([1.])
# tensor([ -7., -10.]) tensor([-17.])
# tensor([-7.,  0.]) tensor([-7.])
# tensor([-7.,  5.]) tensor([-2.])
# tensor([-7.,  9.]) tensor([2.])
# tensor([-2.,  3.]) tensor([1.])
# tensor([7., 3.]) tensor([10.])
# tensor([-8., -4.]) tensor([-12.])
# tensor([4., 5.]) tensor([9.])
# tensor([6., 0.]) tensor([6.])
# tensor([-3.,  3.]) tensor([0.])
# tensor([-7., -6.]) tensor([-13.])
# tensor([-8., -6.]) tensor([-14.])
# tensor([-10.,  -2.]) tensor([-12.])
# tensor([-5.,  9.]) tensor([4.])
# tensor([ 4., -1.]) tensor([3.])
# tensor([ 7., -7.]) tensor([0.])
# tensor([6., 1.]) tensor([7.])
# tensor([-4., -7.]) tensor([-11.])
# tensor([-8.,  2.]) tensor([-6.])
# tensor([ 10., -10.]) tensor([0.])
# tensor([9., 9.]) tensor([18.])
# tensor([ 0., -4.]) tensor([-4.])
# tensor([-8., -9.]) tensor([-17.])
# tensor([-4., -3.]) tensor([-7.])
# tensor([-3.,  7.]) tensor([4.])
# tensor([ 8., -7.]) tensor([1.])
# tensor([ 9., -5.]) tensor([4.])
# tensor([ 4., -6.]) tensor([-2.])
# tensor([-7., -9.]) tensor([-16.])
# tensor([-8.,  6.]) tensor([-2.])
# tensor([-4.,  6.]) tensor([2.])
# tensor([ 0., -5.]) tensor([-5.])
# tensor([ 8., -7.]) tensor([1.])
# tensor([ 4., -1.]) tensor([3.])
# tensor([7., 3.]) tensor([10.])
# tensor([1., 4.]) tensor([5.])
# tensor([10.,  3.]) tensor([13.])
# tensor([-7., -5.]) tensor([-12.])
# tensor([  3., -10.]) tensor([-7.])
# tensor([ 7., -8.]) tensor([-1.])
# tensor([-7., -7.]) tensor([-14.])
# tensor([-7.,  4.]) tensor([-3.])
# tensor([ 0., -1.]) tensor([-1.])
# tensor([  8., -10.]) tensor([-2.])
# tensor([-5., -3.]) tensor([-8.])
# tensor([-5., -3.]) tensor([-8.])
# tensor([3., 7.]) tensor([10.])
# tensor([ 2., -7.]) tensor([-5.])
# tensor([6., 5.]) tensor([11.])
# tensor([ -1., -10.]) tensor([-11.])
# tensor([-8.,  4.]) tensor([-4.])
# tensor([-2., 10.]) tensor([8.])
# tensor([-3., -8.]) tensor([-11.])
# tensor([-10.,   9.]) tensor([-1.])
# tensor([ 4., 10.]) tensor([14.])
# tensor([-9., 10.]) tensor([1.])
# tensor([-9., -3.]) tensor([-12.])
# tensor([-9.,  3.]) tensor([-6.])
# tensor([ 8., 10.]) tensor([18.])
# tensor([9., 0.]) tensor([9.])
# tensor([ 3., -8.]) tensor([-5.])
# tensor([-6., -1.]) tensor([-7.])
# tensor([-2.,  8.]) tensor([6.])
# tensor([-2., -7.]) tensor([-9.])
# tensor([10., -7.]) tensor([3.])
# tensor([3., 6.]) tensor([9.])
# tensor([-1., 10.]) tensor([9.])
# tensor([-9., -3.]) tensor([-12.])
# tensor([ 4., 10.]) tensor([14.])
# tensor([ 2., -5.]) tensor([-3.])
# tensor([10.,  9.]) tensor([19.])
# tensor([-8., -1.]) tensor([-9.])
# tensor([-9.,  4.]) tensor([-5.])
# tensor([8., 3.]) tensor([11.])
# tensor([-6.,  2.]) tensor([-4.])
# tensor([ 5., -9.]) tensor([-4.])
# tensor([ 8., -6.]) tensor([2.])
# tensor([ 4., -6.]) tensor([-2.])
# tensor([ 1., -5.]) tensor([-4.])
# tensor([-7., -7.]) tensor([-14.])
# tensor([ 2., -3.]) tensor([-1.])
# tensor([-1.,  7.]) tensor([6.])
# tensor([7., 1.]) tensor([8.])
# tensor([2., 2.]) tensor([4.])
# tensor([-3., -2.]) tensor([-5.])
# tensor([3., 2.]) tensor([5.])
# tensor([7., 7.]) tensor([14.])
# tensor([1., 8.]) tensor([9.])
# tensor([1., 3.]) tensor([4.])
# tensor([-9., -8.]) tensor([-17.])
# tensor([9., 1.]) tensor([10.])
# tensor([-3., -6.]) tensor([-9.])
# tensor([-10.,   4.]) tensor([-6.])
# tensor([-2.,  7.]) tensor([5.])
# tensor([6., 1.]) tensor([7.])
# tensor([1., 5.]) tensor([6.])
# tensor([-10.,   2.]) tensor([-8.])
# tensor([-8., -7.]) tensor([-15.])
# tensor([10.,  1.]) tensor([11.])
# tensor([-5.,  7.]) tensor([2.])
# tensor([-4.,  3.]) tensor([-1.])
# tensor([-3.,  7.]) tensor([4.])
# tensor([10.,  3.]) tensor([13.])
# tensor([ 8., -6.]) tensor([2.])
# tensor([ 7., 10.]) tensor([17.])
# tensor([-10.,  -1.]) tensor([-11.])
# tensor([-2.,  1.]) tensor([-1.])
# tensor([-10.,  -7.]) tensor([-17.])
# tensor([-6., -6.]) tensor([-12.])
# tensor([-2.,  5.]) tensor([3.])
# tensor([5., 9.]) tensor([14.])
# tensor([-5.,  2.]) tensor([-3.])
# tensor([ -6., -10.]) tensor([-16.])
# tensor([10., -5.]) tensor([5.])
# tensor([-8., -8.]) tensor([-16.])
# tensor([-1., -5.]) tensor([-6.])
# tensor([5., 9.]) tensor([14.])
# tensor([-2.,  0.]) tensor([-2.])
# tensor([ -2., -10.]) tensor([-12.])
# ...
# tensor([-5., -6.]) tensor([-11.])
# tensor([-1.,  1.]) tensor([0.])
# tensor([-7., -5.]) tensor([-12.])
# tensor([-6.,  6.]) tensor([0.])
# tensor([ 8., -9.]) tensor([-1.])
# tensor([3., 3.]) tensor([6.])
# tensor([ 5., -5.]) tensor([0.])
# tensor([ 4., -8.]) tensor([-4.])
# tensor([ 3., -4.]) tensor([-1.])
# tensor([-8.,  7.]) tensor([-1.])
# tensor([-6., -6.]) tensor([-12.])
# tensor([8., 4.]) tensor([12.])
# tensor([-6.,  4.]) tensor([-2.])
# tensor([ -8., -10.]) tensor([-18.])
# tensor([ 4., 10.]) tensor([14.])
# tensor([3., 7.]) tensor([10.])
# tensor([2., 6.]) tensor([8.])
# tensor([ 8., -6.]) tensor([2.])
# tensor([-2.,  5.]) tensor([3.])
# tensor([9., 7.]) tensor([16.])
# tensor([3., 0.]) tensor([3.])
# tensor([ 4., -7.]) tensor([-3.])
# tensor([ 10., -10.]) tensor([0.])
# tensor([ 4., 10.]) tensor([14.])
# tensor([-10.,  -1.]) tensor([-11.])
# tensor([-9., -4.]) tensor([-13.])
# tensor([3., 1.]) tensor([4.])
# tensor([-7., -8.]) tensor([-15.])
# tensor([3., 5.]) tensor([8.])
# tensor([-7.,  4.]) tensor([-3.])
# tensor([-10.,   7.]) tensor([-3.])
# tensor([ 1., -5.]) tensor([-4.])
# tensor([ 7., -6.]) tensor([1.])
# tensor([-6., -3.]) tensor([-9.])
# tensor([ -4., -10.]) tensor([-14.])
# tensor([9., 1.]) tensor([10.])
# tensor([-1., -4.]) tensor([-5.])
# tensor([-8.,  2.]) tensor([-6.])
# tensor([9., 7.]) tensor([16.])
# tensor([-9.,  6.]) tensor([-3.])
# tensor([-7., -8.]) tensor([-15.])
# tensor([-10.,   9.]) tensor([-1.])
# tensor([ 5., 10.]) tensor([15.])
# tensor([ 2., -1.]) tensor([1.])
# tensor([-10.,  -4.]) tensor([-14.])
# tensor([ -4., -10.]) tensor([-14.])
# tensor([ 3., -9.]) tensor([-6.])
# tensor([2., 9.]) tensor([11.])
# tensor([-1., -6.]) tensor([-7.])
# tensor([4., 5.]) tensor([9.])
# tensor([10., -5.]) tensor([5.])
# tensor([9., 7.]) tensor([16.])
# tensor([ 2., -3.]) tensor([-1.])
# tensor([ 2., -5.]) tensor([-3.])
# tensor([3., 8.]) tensor([11.])
# tensor([-9., -3.]) tensor([-12.])
# tensor([-8.,  5.]) tensor([-3.])
# tensor([-5.,  2.]) tensor([-3.])
# tensor([-5.,  2.]) tensor([-3.])
# tensor([1., 3.]) tensor([4.])
# tensor([-3., -6.]) tensor([-9.])
# tensor([-9.,  3.]) tensor([-6.])
# tensor([-1., -3.]) tensor([-4.])
# tensor([-8.,  3.]) tensor([-5.])
# tensor([5., 4.]) tensor([9.])
# tensor([-1., 10.]) tensor([9.])
# tensor([ 3., -7.]) tensor([-4.])
# tensor([-10.,   3.]) tensor([-7.])
# tensor([7., 2.]) tensor([9.])
# tensor([9., 3.]) tensor([12.])
# tensor([-10.,   0.]) tensor([-10.])
# tensor([-1.,  3.]) tensor([2.])
# tensor([  7., -10.]) tensor([-3.])
# tensor([6., 7.]) tensor([13.])
# tensor([4., 8.]) tensor([12.])
# tensor([ 6., -2.]) tensor([4.])
# tensor([ 5., -9.]) tensor([-4.])
# tensor([7., 6.]) tensor([13.])
# tensor([ 9., -1.]) tensor([8.])
# tensor([ -3., -10.]) tensor([-13.])
# tensor([2., 5.]) tensor([7.])
# tensor([-1.,  1.]) tensor([0.])
# tensor([-9.,  5.]) tensor([-4.])
# tensor([10.,  6.]) tensor([16.])
# tensor([-1., -5.]) tensor([-6.])
# tensor([4., 2.]) tensor([6.])
# tensor([-5., -2.]) tensor([-7.])
# tensor([ 8., -1.]) tensor([7.])
# tensor([-4.,  3.]) tensor([-1.])
# tensor([10.,  8.]) tensor([18.])
# tensor([ 7., -1.]) tensor([6.])
# tensor([-6., -5.]) tensor([-11.])
# tensor([4., 5.]) tensor([9.])
# tensor([8., 0.]) tensor([8.])
# tensor([ 8., -4.]) tensor([4.])
# tensor([7., 3.]) tensor([10.])
# tensor([-6.,  1.]) tensor([-5.])
# tensor([-7.,  8.]) tensor([1.])
# tensor([-2.,  7.]) tensor([5.])
# tensor([7., 0.]) tensor([7.])
# tensor([-10.,  -8.]) tensor([-18.])
# tensor([-6.,  7.]) tensor([1.])
# tensor([-8., -9.]) tensor([-17.])
# tensor([5., 8.]) tensor([13.])
# tensor([6., 0.]) tensor([6.])
# tensor([-1., -8.]) tensor([-9.])
# tensor([-6.,  4.]) tensor([-2.])
# tensor([ 5., -6.]) tensor([-1.])
# tensor([3., 4.]) tensor([7.])
# tensor([4., 1.]) tensor([5.])
# tensor([4., 4.]) tensor([8.])
# tensor([-9., -7.]) tensor([-16.])
# tensor([ 5., -5.]) tensor([0.])
# tensor([-4., -2.]) tensor([-6.])
# tensor([8., 7.]) tensor([15.])
# tensor([ 2., -6.]) tensor([-4.])
# tensor([9., 1.]) tensor([10.])
# tensor([-6., -3.]) tensor([-9.])
# tensor([-9.,  6.]) tensor([-3.])
# tensor([-5.,  9.]) tensor([4.])
# tensor([ 8., -4.]) tensor([4.])
# tensor([-5.,  2.]) tensor([-3.])
# tensor([9., 8.]) tensor([17.])
# tensor([ 4., -7.]) tensor([-3.])
# tensor([10.,  5.]) tensor([15.])
# tensor([ 0., -7.]) tensor([-7.])
# tensor([-6.,  5.]) tensor([-1.])
# tensor([4., 3.]) tensor([7.])
# tensor([5., 3.]) tensor([8.])
# tensor([4., 7.]) tensor([11.])
# tensor([7., 6.]) tensor([13.])
# tensor([-3.,  5.]) tensor([2.])
# tensor([ 6., -1.]) tensor([5.])
# tensor([-4.,  4.]) tensor([0.])
# tensor([-9.,  2.]) tensor([-7.])
# tensor([  7., -10.]) tensor([-3.])
# tensor([ 6., -4.]) tensor([2.])
# tensor([5., 6.]) tensor([11.])
# tensor([7., 3.]) tensor([10.])
# tensor([-6., -3.]) tensor([-9.])
# tensor([8., 3.]) tensor([11.])
# tensor([  8., -10.]) tensor([-2.])
# tensor([-9.,  1.]) tensor([-8.])
# tensor([10.,  8.]) tensor([18.])
# tensor([-1.,  8.]) tensor([7.])
# tensor([5., 4.]) tensor([9.])
# tensor([-5.,  2.]) tensor([-3.])
# tensor([ 6., -8.]) tensor([-2.])
# tensor([10.,  6.]) tensor([16.])
# tensor([-10.,  -5.]) tensor([-15.])
# tensor([10.,  7.]) tensor([17.])
# tensor([ -4., -10.]) tensor([-14.])
# tensor([-8.,  6.]) tensor([-2.])
# tensor([7., 9.]) tensor([16.])
# tensor([10., -8.]) tensor([2.])
# tensor([-4.,  7.]) tensor([3.])
# tensor([-1., -7.]) tensor([-8.])
# tensor([-8., -9.]) tensor([-17.])
# tensor([ 0., -3.]) tensor([-3.])
# tensor([-10.,   4.]) tensor([-6.])
# tensor([ 0., -9.]) tensor([-9.])
# tensor([-10.,   0.]) tensor([-10.])
# tensor([-4.,  7.]) tensor([3.])
# tensor([-3., -3.]) tensor([-6.])
# tensor([-2., -8.]) tensor([-10.])
# tensor([8., 0.]) tensor([8.])
# tensor([6., 8.]) tensor([14.])
# tensor([ 0., -1.]) tensor([-1.])
# tensor([-9.,  1.]) tensor([-8.])
# tensor([-8.,  6.]) tensor([-2.])
# tensor([-5.,  8.]) tensor([3.])
# tensor([ 6., 10.]) tensor([16.])
# tensor([-1.,  4.]) tensor([3.])
# tensor([ 8., -1.]) tensor([7.])
# tensor([ 1., 10.]) tensor([11.])
# tensor([-9., -3.]) tensor([-12.])
# tensor([-1., -2.]) tensor([-3.])
# tensor([4., 5.]) tensor([9.])
# tensor([ 8., -9.]) tensor([-1.])
# tensor([ 3., -4.]) tensor([-1.])
# tensor([-10.,   2.]) tensor([-8.])
# tensor([-5.,  0.]) tensor([-5.])
# tensor([-8.,  4.]) tensor([-4.])
# tensor([6., 8.]) tensor([14.])
# tensor([3., 8.]) tensor([11.])
# tensor([-6., -7.]) tensor([-13.])
# tensor([-2., -6.]) tensor([-8.])
# tensor([-2., -8.]) tensor([-10.])
# tensor([3., 5.]) tensor([8.])
# tensor([2., 4.]) tensor([6.])
# tensor([5., 7.]) tensor([12.])
# tensor([-2.,  9.]) tensor([7.])
# tensor([-4.,  4.]) tensor([0.])
# tensor([-9.,  0.]) tensor([-9.])
# tensor([3., 4.]) tensor([7.])
# tensor([-10.,  -4.]) tensor([-14.])
# tensor([-4.,  0.]) tensor([-4.])
# tensor([ 5., -3.]) tensor([2.])
# tensor([-4.,  2.]) tensor([-2.])
# tensor([-1., -4.]) tensor([-5.])
# tensor([-7., -5.]) tensor([-12.])
# tensor([  6., -10.]) tensor([-4.])
# tensor([-8.,  5.]) tensor([-3.])
# tensor([-5.,  7.]) tensor([2.])
# tensor([5., 0.]) tensor([5.])
# tensor([1., 3.]) tensor([4.])
# tensor([-8., -6.]) tensor([-14.])
# tensor([ 7., -7.]) tensor([0.])
# tensor([ 3., -8.]) tensor([-5.])
# tensor([-5.,  5.]) tensor([0.])
# tensor([-2., -6.]) tensor([-8.])
# tensor([3., 1.]) tensor([4.])
# tensor([-9.,  0.]) tensor([-9.])
# tensor([10., -2.]) tensor([8.])
# tensor([-9.,  0.]) tensor([-9.])
# tensor([-8., -8.]) tensor([-16.])
# tensor([-5.,  7.]) tensor([2.])
# tensor([-6., -5.]) tensor([-11.])
# tensor([-4., -4.]) tensor([-8.])
# tensor([-4.,  3.]) tensor([-1.])
# tensor([-2., 10.]) tensor([8.])
# tensor([10., -7.]) tensor([3.])
# tensor([ 7., -8.]) tensor([-1.])
# tensor([ 7., -9.]) tensor([-2.])
# tensor([-9., -9.]) tensor([-18.])
# tensor([-9., 10.]) tensor([1.])
# tensor([-9., -3.]) tensor([-12.])
# tensor([9., 0.]) tensor([9.])
# tensor([  3., -10.]) tensor([-7.])
# tensor([-5.,  0.]) tensor([-5.])
# tensor([-1., -3.]) tensor([-4.])
# tensor([-3., -8.]) tensor([-11.])
# tensor([5., 9.]) tensor([14.])
# tensor([-8.,  2.]) tensor([-6.])
# tensor([8., 7.]) tensor([15.])
# tensor([-8.,  4.]) tensor([-4.])
# tensor([ 9., -9.]) tensor([0.])
# tensor([4., 1.]) tensor([5.])
# tensor([-7., -6.]) tensor([-13.])
# tensor([-10.,   3.]) tensor([-7.])
# tensor([-10.,   6.]) tensor([-4.])
# tensor([ 7., -4.]) tensor([3.])
# tensor([6., 4.]) tensor([10.])
# tensor([5., 0.]) tensor([5.])
# tensor([8., 8.]) tensor([16.])
# tensor([ 9., -1.]) tensor([8.])
# tensor([ 7., -8.]) tensor([-1.])
# tensor([-4., -1.]) tensor([-5.])
# tensor([-9.,  3.]) tensor([-6.])
# tensor([-6.,  4.]) tensor([-2.])
# tensor([ -1., -10.]) tensor([-11.])
# tensor([2., 5.]) tensor([7.])
# tensor([-8., -5.]) tensor([-13.])
# tensor([-4., -4.]) tensor([-8.])
# tensor([ 8., -6.]) tensor([2.])
# tensor([-10.,   2.]) tensor([-8.])
# tensor([ 5., -5.]) tensor([0.])
# tensor([ 1., -7.]) tensor([-6.])
# tensor([0., 3.]) tensor([3.])
# tensor([-8.,  0.]) tensor([-8.])
# tensor([-4.,  9.]) tensor([5.])
# tensor([-3.,  5.]) tensor([2.])
# tensor([-7., -9.]) tensor([-16.])
# tensor([ 3., -8.]) tensor([-5.])
# tensor([7., 4.]) tensor([11.])
# tensor([ 3., -9.]) tensor([-6.])
# tensor([5., 4.]) tensor([9.])
# tensor([ 6., -1.]) tensor([5.])
# tensor([-2., -5.]) tensor([-7.])
# tensor([ 9., -5.]) tensor([4.])
# tensor([2., 6.]) tensor([8.])
# tensor([-5.,  2.]) tensor([-3.])
# tensor([-5.,  1.]) tensor([-4.])
# tensor([0., 5.]) tensor([5.])
# tensor([-3.,  9.]) tensor([6.])
# tensor([-6., -3.]) tensor([-9.])
# tensor([-9.,  4.]) tensor([-5.])
# tensor([-2.,  5.]) tensor([3.])
# tensor([-2., -4.]) tensor([-6.])
# tensor([-8.,  1.]) tensor([-7.])
# tensor([ 5., -5.]) tensor([0.])
# tensor([2., 8.]) tensor([10.])
# tensor([ 2., 10.]) tensor([12.])
# tensor([-10.,   4.]) tensor([-6.])
# tensor([-9., -7.]) tensor([-16.])
# tensor([-3., -9.]) tensor([-12.])
# tensor([-2.,  6.]) tensor([4.])
# tensor([4., 3.]) tensor([7.])
# tensor([ 2., -4.]) tensor([-2.])
# tensor([ 8., -4.]) tensor([4.])
# tensor([5., 0.]) tensor([5.])
# tensor([4., 9.]) tensor([13.])
# tensor([-8., -8.]) tensor([-16.])
# tensor([-8., -5.]) tensor([-13.])
# tensor([-10.,  -5.]) tensor([-15.])
# tensor([-2., -2.]) tensor([-4.])
# tensor([8., 4.]) tensor([12.])
# tensor([ 1., -8.]) tensor([-7.])
# tensor([  8., -10.]) tensor([-2.])
# tensor([-6.,  8.]) tensor([2.])
# tensor([-1., -5.]) tensor([-6.])
# tensor([-10.,  -7.]) tensor([-17.])
# tensor([-9.,  1.]) tensor([-8.])
# tensor([-1., -3.]) tensor([-4.])
# tensor([ 9., -1.]) tensor([8.])
# tensor([3., 6.]) tensor([9.])
# tensor([-1., -5.]) tensor([-6.])
# tensor([4., 8.]) tensor([12.])
# tensor([-1.,  2.]) tensor([1.])
# tensor([ 4., -9.]) tensor([-5.])
# tensor([-7.,  2.]) tensor([-5.])
# tensor([-9.,  3.]) tensor([-6.])
# tensor([6., 5.]) tensor([11.])
# tensor([-8., 10.]) tensor([2.])
# tensor([7., 7.]) tensor([14.])
# tensor([-7., -8.]) tensor([-15.])
# tensor([3., 9.]) tensor([12.])
# tensor([ 3., -9.]) tensor([-6.])
# tensor([-5.,  3.]) tensor([-2.])
# tensor([7., 3.]) tensor([10.])
# tensor([ 4., -4.]) tensor([0.])
# tensor([-4.,  3.]) tensor([-1.])
# tensor([ 8., -2.]) tensor([6.])
# tensor([-6., -8.]) tensor([-14.])
# tensor([7., 4.]) tensor([11.])
# tensor([-10.,  -3.]) tensor([-13.])
# tensor([  1., -10.]) tensor([-9.])
# tensor([5., 3.]) tensor([8.])
# tensor([7., 3.]) tensor([10.])
# tensor([6., 1.]) tensor([7.])
# tensor([1., 1.]) tensor([2.])
# tensor([ 5., -6.]) tensor([-1.])
# tensor([10., 10.]) tensor([20.])
# tensor([6., 9.]) tensor([15.])
# tensor([-6., -9.]) tensor([-15.])
# tensor([-6., -8.]) tensor([-14.])
# tensor([3., 0.]) tensor([3.])
# tensor([9., 6.]) tensor([15.])
# tensor([ 3., -3.]) tensor([0.])
# tensor([6., 7.]) tensor([13.])
# tensor([-7.,  0.]) tensor([-7.])
# tensor([-7., -5.]) tensor([-12.])
# tensor([-3.,  2.]) tensor([-1.])
# tensor([-8.,  0.]) tensor([-8.])
# tensor([  1., -10.]) tensor([-9.])
# tensor([-5.,  2.]) tensor([-3.])
# tensor([ 7., -1.]) tensor([6.])
# tensor([-6.,  2.]) tensor([-4.])
# tensor([-10.,  -2.]) tensor([-12.])
# tensor([9., 5.]) tensor([14.])
# tensor([ 1., -4.]) tensor([-3.])
# tensor([5., 6.]) tensor([11.])
# tensor([-8.,  0.]) tensor([-8.])
# tensor([  7., -10.]) tensor([-3.])
# tensor([-5.,  9.]) tensor([4.])
# tensor([-4., -3.]) tensor([-7.])
# tensor([-5.,  0.]) tensor([-5.])
# tensor([ 7., -7.]) tensor([0.])
# tensor([-2., -3.]) tensor([-5.])
# tensor([0., 5.]) tensor([5.])
# tensor([5., 9.]) tensor([14.])
# tensor([-8., -9.]) tensor([-17.])
# tensor([8., 5.]) tensor([13.])
# tensor([5., 9.]) tensor([14.])
# tensor([-5., -3.]) tensor([-8.])
# tensor([-1.,  6.]) tensor([5.])
# tensor([1., 4.]) tensor([5.])
# tensor([-7., -4.]) tensor([-11.])
# tensor([-2., 10.]) tensor([8.])
# tensor([ 5., -4.]) tensor([1.])
# tensor([-6.,  2.]) tensor([-4.])
# tensor([ 8., -2.]) tensor([6.])
# tensor([5., 9.]) tensor([14.])
# tensor([-10.,   2.]) tensor([-8.])
# tensor([-10.,  -2.]) tensor([-12.])
# tensor([4., 9.]) tensor([13.])
# tensor([1., 6.]) tensor([7.])
# tensor([-7., -9.]) tensor([-16.])
# tensor([-8., -8.]) tensor([-16.])
# tensor([ 8., -8.]) tensor([0.])
# tensor([-10.,   1.]) tensor([-9.])
# tensor([ 8., -1.]) tensor([7.])
# tensor([-6., 10.]) tensor([4.])
# tensor([6., 7.]) tensor([13.])
# tensor([6., 4.]) tensor([10.])
# tensor([-7., -8.]) tensor([-15.])
# tensor([-5., -2.]) tensor([-7.])
# tensor([ 6., -1.]) tensor([5.])
# tensor([9., 8.]) tensor([17.])
# tensor([10.,  1.]) tensor([11.])
# tensor([ 3., -2.]) tensor([1.])
# tensor([-8., -2.]) tensor([-10.])
# tensor([-2.,  9.]) tensor([7.])
# tensor([-7.,  1.]) tensor([-6.])
# tensor([ 8., -9.]) tensor([-1.])
# tensor([-10.,   8.]) tensor([-2.])
# tensor([-5., -8.]) tensor([-13.])
# tensor([0., 8.]) tensor([8.])
# tensor([-3.,  6.]) tensor([3.])
# tensor([1., 5.]) tensor([6.])
# tensor([9., 2.]) tensor([11.])
# tensor([-4.,  9.]) tensor([5.])
# tensor([1., 0.]) tensor([1.])
# tensor([-2.,  0.]) tensor([-2.])
# tensor([-4., -3.]) tensor([-7.])
# tensor([-9., -7.]) tensor([-16.])
# tensor([-5.,  4.]) tensor([-1.])
# tensor([-10.,   5.]) tensor([-5.])
# tensor([-1., -5.]) tensor([-6.])
# tensor([ 3., -7.]) tensor([-4.])
# tensor([-9.,  6.]) tensor([-3.])
# tensor([ 5., -3.]) tensor([2.])
# tensor([-8.,  4.]) tensor([-4.])
# tensor([-1.,  0.]) tensor([-1.])
# tensor([ -8., -10.]) tensor([-18.])
# tensor([-9., -3.]) tensor([-12.])
# tensor([-9., -4.]) tensor([-13.])
# tensor([4., 8.]) tensor([12.])
# tensor([-1.,  4.]) tensor([3.])
# tensor([-8.,  1.]) tensor([-7.])
# tensor([-4., -4.]) tensor([-8.])
# tensor([ 6., -5.]) tensor([1.])
# tensor([-5., -8.]) tensor([-13.])
# tensor([ -7., -10.]) tensor([-17.])
# tensor([-2., -6.]) tensor([-8.])
# tensor([ 1., -4.]) tensor([-3.])
# tensor([-1.,  9.]) tensor([8.])
# tensor([0., 6.]) tensor([6.])
# tensor([ 5., -9.]) tensor([-4.])
# tensor([  3., -10.]) tensor([-7.])
# tensor([7., 6.]) tensor([13.])
# tensor([ 0., -3.]) tensor([-3.])
# tensor([ 7., -3.]) tensor([4.])
# tensor([ 5., -4.]) tensor([1.])
# tensor([ -7., -10.]) tensor([-17.])
# tensor([-3., -6.]) tensor([-9.])
# tensor([2., 3.]) tensor([5.])
# tensor([ 3., -6.]) tensor([-3.])
# tensor([-8.,  7.]) tensor([-1.])
# tensor([10.,  0.]) tensor([10.])
# tensor([ 2., -3.]) tensor([-1.])
# tensor([1., 6.]) tensor([7.])
# tensor([ 9., -2.]) tensor([7.])
# tensor([ 6., -8.]) tensor([-2.])
# tensor([-9.,  2.]) tensor([-7.])
# tensor([-6.,  4.]) tensor([-2.])
# tensor([-7., -8.]) tensor([-15.])
# tensor([-10.,  -9.]) tensor([-19.])
# tensor([-6.,  9.]) tensor([3.])
# tensor([-3.,  3.]) tensor([0.])
# tensor([ 0., -1.]) tensor([-1.])
# tensor([0., 1.]) tensor([1.])
# tensor([-9.,  7.]) tensor([-2.])
# tensor([10., -4.]) tensor([6.])
# tensor([-4., -1.]) tensor([-5.])
# tensor([1., 9.]) tensor([10.])
# tensor([ 2., -7.]) tensor([-5.])
# tensor([-3., -9.]) tensor([-12.])
# tensor([ 6., -8.]) tensor([-2.])
# tensor([8., 3.]) tensor([11.])
# tensor([  8., -10.]) tensor([-2.])
# tensor([4., 7.]) tensor([11.])
# tensor([10., -1.]) tensor([9.])
# tensor([-3., -9.]) tensor([-12.])
# tensor([6., 6.]) tensor([12.])
# tensor([4., 9.]) tensor([13.])
# tensor([-3., -2.]) tensor([-5.])
# tensor([4., 8.]) tensor([12.])
# tensor([-1.,  8.]) tensor([7.])
# tensor([-9., -6.]) tensor([-15.])
# tensor([-10.,   1.]) tensor([-9.])
# tensor([-2., -7.]) tensor([-9.])
# tensor([-1.,  0.]) tensor([-1.])
# tensor([-2., -4.]) tensor([-6.])
# tensor([-1., -5.]) tensor([-6.])
# tensor([ 7., -4.]) tensor([3.])
# tensor([  1., -10.]) tensor([-9.])
# tensor([-5., -3.]) tensor([-8.])
# tensor([-3., -1.]) tensor([-4.])
# tensor([8., 5.]) tensor([13.])
# tensor([-4., -9.]) tensor([-13.])
# tensor([ 7., -3.]) tensor([4.])
# tensor([ 4., -4.]) tensor([0.])
# tensor([ 7., -8.]) tensor([-1.])
# tensor([10.,  4.]) tensor([14.])
# tensor([6., 3.]) tensor([9.])
# tensor([6., 0.]) tensor([6.])
# tensor([-4.,  5.]) tensor([1.])
# tensor([2., 2.]) tensor([4.])
# tensor([ -8., -10.]) tensor([-18.])
# tensor([10.,  2.]) tensor([12.])

# %%
labels.shape

# %% [markdown]
# # Design the model

# %%
# a function that builds the model

def createADDmodel():

  # model architecture
  ADDclassify = nn.Sequential(
      nn.Linear(2,30),  # input layer
      nn.ReLU(),        # activation unit
      nn.Linear(30,1),  # hidden layer
      nn.ReLU(),        # activation unit
      nn.Linear(1,1),   # output unit
        )

  # loss function
  lossfun = nn.MSELoss()

  # optimizer
  optimizer = torch.optim.Adam(ADDclassify.parameters(),lr=.01)

  # model output
  return ADDclassify,lossfun,optimizer

# %% [markdown]
# # Train the model

# %%
# a function that trains the model

# a fixed parameter
numepochs = 10

def trainTheModel(ADDmodel):

  # initialize losses
  losses = torch.zeros(numepochs)

  # loop over epochs
  for epochi in range(numepochs):

    numloss = []
    # loop through "minibatches" of N=1
    for num,ans in zip(data,labels):

      # forward pass
      yHat = ADDmodel(num)

      # compute loss
      loss = lossfun(yHat,ans)
      numloss.append(loss.item())

      # backprop
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

  losses[epochi] = np.mean(numloss)


  # final forward pass
  with torch.no_grad():
    predictions = ADDmodel(data)

  # compute the predictions and report accuracy (is this really different from loss?)
  trainacc = 100*torch.mean( (np.abs(predictions-labels)<1).float() ) # <1 for rounding


  ### now test with new data!
  # create brand new test data
  TESTdata = torch.randint(low=-10,high=11,size=(N,2)).float()
  TESTlabels = torch.sum(TESTdata,axis=1,keepdim=True)

  # evaluate the model and compute accuracy
  with torch.no_grad():
    predictions = ADDmodel(TESTdata)
  testacc = 100*torch.mean( (np.abs(predictions-TESTlabels)<1).float() )

  # EOF
  return losses,trainacc,testacc,ADDmodel

# %%
# test the model once to make sure it runs
AddingMachine,lossfun,optimizer = createADDmodel()
losses,trainacc,testacc,ADDmodel = trainTheModel(AddingMachine)

# print the results
trainacc,testacc
# losses
# Out:
# (tensor(99.5500), tensor(99.3500))

# %% [markdown]
# # Run the experiment!

# %%
# run the model 10 times to check reproducibility

for i in range(10):

  # create a new 'machine' and train it
  AddingMachine,lossfun,optimizer = createADDmodel()
  _,trainacc,testacc,ADDmodel = trainTheModel(AddingMachine)

  # report accuracy
  print('Model instance %s, final TRAIN/TEST accuracies: %g%%, %g%%' %(i+1,trainacc,testacc))
# Out:
# Model instance 1, final TRAIN/TEST accuracies: 99.75%, 99.85%
# Model instance 2, final TRAIN/TEST accuracies: 98.6%, 98.2%
# Model instance 3, final TRAIN/TEST accuracies: 99.55%, 99.35%
# Model instance 4, final TRAIN/TEST accuracies: 8.9%, 8.85%
# Model instance 5, final TRAIN/TEST accuracies: 99.75%, 99.5%
# Model instance 6, final TRAIN/TEST accuracies: 8.9%, 8.45%
# Model instance 7, final TRAIN/TEST accuracies: 99.75%, 99.95%
# Model instance 8, final TRAIN/TEST accuracies: 99.75%, 99.75%
# Model instance 9, final TRAIN/TEST accuracies: 99.65%, 99.75%
# Model instance 10, final TRAIN/TEST accuracies: 99.75%, 99.85%

# %%
# some plots from the final model

data = torch.randint(low=-10,high=11,size=(N,2)).float()
labels = torch.sum(data,axis=1,keepdim=True)

# evaluate the model and compute accuracy
with torch.no_grad():
  predictions = ADDmodel(data)


# true and predicted values
fig = plt.figure(figsize=(15,5))
plt.plot(labels,'s')
plt.plot(np.round(predictions.detach()),'rx')
plt.legend(['True sum','Predicted sum'])
plt.xlabel('Sample index')
plt.ylabel('Sum')
plt.title('Predicted vs. actual sum')
plt.show()
